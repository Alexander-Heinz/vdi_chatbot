# %%
import json

with open('documents-with-ids.json', 'rt') as f_in:
    documents = json.load(f_in)

# %%
from elasticsearch import Elasticsearch

# Create Elasticsearch client
es_client = Elasticsearch('http://localhost:9200')

# Define index settings with mappings matching your column names
index_settings = {
    "settings": {
        "number_of_shards": 1,
        "number_of_replicas": 0
    },
    "mappings": {
        "properties": {
            "Category": {"type": "keyword"},  # Category as a keyword
            "Question": {"type": "text"},     # Question as text (full-text search)
            "Answer": {"type": "text"},       # Answer as text (full-text search)
            "id": {"type": "keyword"},        # id as a keyword (for unique identification)
        }
    }
}

index_name = "faq_index"

# Delete index if it exists
es_client.indices.delete(index=index_name, ignore_unavailable=True)

# Create the new index
es_client.indices.create(index=index_name, body=index_settings)
# Out:
# /var/folders/81/16mr_0gj603btxm2xxhl704c0000gn/T/ipykernel_48040/1453844283.py:28: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   es_client.indices.create(index=index_name, body=index_settings)
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'faq_index'})

# %%
from tqdm.auto import tqdm

for doc in tqdm(documents):
    es_client.index(index=index_name, document=doc)
# Out:
# 100%|██████████| 833/833 [00:03<00:00, 215.05it/s]

# %%
def elastic_search(query, category=None):
    search_query = {
        "size": 5,  # Limit the search to 5 results
        "query": {
            "bool": {
                "must": {
                    "multi_match": {
                        "query": query,
                        "fields": ["Question^3", "Answer", "Category"],  # Search in 'Question' and 'Answer' fields, include category
                        "type": "most_fields"  # Use 'best_fields' for matching
                    }
                }
            }
        }
    }

    # Add a filter if a category is specified
    if category:
        search_query['query']['bool']['filter'] = {
            "term": {
                "Category": category  # Filter based on 'Category'
            }
        }

    # Execute the search query on the 'faq-documents' index
    response = es_client.search(index=index_name, body=search_query)
    
    # Collect the search results
    result_docs = []
    for hit in response['hits']['hits']:
        result_docs.append(hit['_source'])
    
    return result_docs

# %%
# elastic_search(
#     query="I just discovered the course. Can I still join?",
#     category="data-engineering-zoomcamp"
# )

# %%
import pandas as pd

# %%
df_ground_truth = pd.read_csv('ground-truth-data_old.csv')

# %%
ground_truth = df_ground_truth.to_dict(orient='records')

# %%
ground_truth
# Out:
# [{'Question': 'Welche Unterlagen müssen zur Bonitätsprüfung eingereicht werden?',
#   'Category': '--Bonitätsprüfung',
#   'Document': 'bead1965'},
#  {'Question': 'Wer wird zur Bonitätsprüfung aufgefordert?',
#   'Category': '--Bonitätsprüfung',
#   'Document': 'bead1965'},
#  {'Question': 'Was passiert, wenn kein geprüfter Jahresabschluss vorliegt?',
#   'Category': '--Bonitätsprüfung',
#   'Document': 'bead1965'},
#  {'Question': 'Was ist der Zweck einer Bonitätsprüfung?',
#   'Category': '--Bonitätsprüfung',
#   'Document': 'bead1965'},
#  {'Question': 'Wo finde ich weitere Informationen zur Bonitätsprüfung?',
#   'Category': '--Bonitätsprüfung',
#   'Document': 'bead1965'},
#  {'Question': 'Darf das Konsortium nur aus akademischen Institutionen bestehen?',
#   'Category': '--Profi-Online',
#   'Document': '99541b90'},
#  {'Question': 'Können nur Forschungseinrichtungen ein Konsortium bilden?',
#   'Category': '--Profi-Online',
#   'Document': '99541b90'},
#  {'Question': 'Sind ausschließlich Forscher für das Konsortium zugelassen?',
#   'Category': '--Profi-Online',
#   'Document': '99541b90'},
#  {'Question': 'Muss das Konsortium aus Forschungseinrichtungen zusammengesetzt sein?',
#   'Category': '--Profi-Online',
#   'Document': '99541b90'},
#  {'Question': 'Sollten nur Forschungseinrichtungen Teil des Konsortiums sein?',
#   'Category': '--Profi-Online',
#   'Document': '99541b90'},
#  {'Question': 'Wie viele Personen können Rechte zur Nutzerverwaltung haben?',
#   'Category': '--Profi-Online',
#   'Document': '84ae26c1'},
#  {'Question': 'Muss jede Organisation mindestens einen Benutzerverwalter haben?',
#   'Category': '--Profi-Online',
#   'Document': '84ae26c1'},
#  {'Question': 'Können nur eine Person Rechte zur Nutzerverwaltung erhalten?',
#   'Category': '--Profi-Online',
#   'Document': '84ae26c1'},
#  {'Question': 'Kann eine Organisation mehrere Benutzerverwalter einrichten?',
#   'Category': '--Profi-Online',
#   'Document': '84ae26c1'},
#  {'Question': 'Ist es verpflichtend, einen Benutzerverwalter zu haben?',
#   'Category': '--Profi-Online',
#   'Document': '84ae26c1'},
#  {'Question': 'Dürfen Projektleiter einen Zugang zu profi-Online erhalten?',
#   'Category': '--Profi-Online',
#   'Document': '0817bd44'},
#  {'Question': 'Können Projektleiter profi-Online nutzen, um Zahlungsanforderungen zu erstellen?',
#   'Category': '--Profi-Online',
#   'Document': '0817bd44'},
#  {'Question': 'Wer entscheidet intern über den profi-Online Zugang für Projektleitende?',
#   'Category': '--Profi-Online',
#   'Document': '0817bd44'},
#  {'Question': 'Müssen Projektleiter einen profi-Online Zugang beantragen, wenn sie Zwischennachweise erstellen?',
#   'Category': '--Profi-Online',
#   'Document': '0817bd44'},
#  {'Question': 'Sollten Projektleiter profi-Online verwenden, wenn sie Zahlungsanforderungen einreichen?',
#   'Category': '--Profi-Online',
#   'Document': '0817bd44'},
#  {'Question': 'Wie erhält man Zugriff auf profi-Online?',
#   'Category': '--Profi-Online',
#   'Document': 'f06cd838'},
#  {'Question': 'Wer genehmigt den Zugang zu profi-Online?',
#   'Category': '--Profi-Online',
#   'Document': 'f06cd838'},
#  {'Question': 'An wen muss man den Antrag für profi-Online senden?',
#   'Category': '--Profi-Online',
#   'Document': 'f06cd838'},
#  {'Question': 'Wer bearbeitet den Einschaltantrag für profi-Online?',
#   'Category': '--Profi-Online',
#   'Document': 'f06cd838'},
#  {'Question': 'Welches Unternehmen ist für die Freischaltung von profi-Online verantwortlich?',
#   'Category': '--Profi-Online',
#   'Document': 'f06cd838'},
#  {'Question': 'Gibt es bestimmte Richtlinien zur Zitierweise im Antrag?',
#   'Category': '--Profi-Online',
#   'Document': 'ea9e8aaa'},
#  {'Question': 'Soll eine einheitliche Zitierweise im Antrag befolgt werden?',
#   'Category': '--Profi-Online',
#   'Document': 'ea9e8aaa'},
#  {'Question': 'Welche Vorgaben gibt es zur Zitierweise im Antrag?',
#   'Category': '--Profi-Online',
#   'Document': 'ea9e8aaa'},
#  {'Question': 'Muss ich auf eine konsistente Zitierweise im Antrag achten?',
#   'Category': '--Profi-Online',
#   'Document': 'ea9e8aaa'},
#  {'Question': 'Gibt es spezielle Anforderungen zur Zitierweise im Antrag?',
#   'Category': '--Profi-Online',
#   'Document': 'ea9e8aaa'},
#  {'Question': 'Sind Ausgaben für kostenpflichtige Literaturdatenbanken in F0840 enthalten?',
#   'Category': '-Antragstellung',
#   'Document': '1846806e'},
#  {'Question': 'Sind Datenbankkosten unter F0840 gedeckt?',
#   'Category': '-Antragstellung',
#   'Document': '1846806e'},
#  {'Question': 'Zahlt F0840 für Literaturdatenbanknutzungen?',
#   'Category': '-Antragstellung',
#   'Document': '1846806e'},
#  {'Question': 'Deckt F0840 auch Literaturdatenbanken?',
#   'Category': '-Antragstellung',
#   'Document': '1846806e'},
#  {'Question': 'Kann ich Datenbankgebühren unter F0840 beantragen?',
#   'Category': '-Antragstellung',
#   'Document': '1846806e'},
#  {'Question': 'Wo finde ich Informationen zur Abschreibung von Geräten?',
#   'Category': '-Antragstellung',
#   'Document': '6bebd8e4'},
#  {'Question': 'Ab welchem Betrag gilt die Abschreibungspflicht für Geräte?',
#   'Category': '-Antragstellung',
#   'Document': '6bebd8e4'},
#  {'Question': 'Gibt es offizielle Tabellen für die Abschreibung von Geräten?',
#   'Category': '-Antragstellung',
#   'Document': '6bebd8e4'},
#  {'Question': 'Wie kann ich die AfA-Tabellen des Bundesfinanzministeriums nutzen?',
#   'Category': '-Antragstellung',
#   'Document': '6bebd8e4'},
#  {'Question': 'Bis zu welchem Betrag können Geräte wie Verbrauchsmaterial bestellt werden?',
#   'Category': '-Antragstellung',
#   'Document': '6bebd8e4'},
#  {'Question': 'Welche Vorschriften müssen bei der Vergabe eines Auftrages beachtet werden?',
#   'Category': '-Antragstellung',
#   'Document': '109ef09e'},
#  {'Question': 'Wo finde ich die Bestimmungen für die Beauftragung?',
#   'Category': '-Antragstellung',
#   'Document': '109ef09e'},
#  {'Question': 'Wer führt die Vergaberechtsberatung durch?',
#   'Category': '-Antragstellung',
#   'Document': '109ef09e'},
#  {'Question': 'Wann muss ich das Vergabeverfahren prüfen?',
#   'Category': '-Antragstellung',
#   'Document': '109ef09e'},
#  {'Question': 'Was versteht man unter NABF im Kontext der Vergabe?',
#   'Category': '-Antragstellung',
#   'Document': '109ef09e'},
#  {'Question': 'Wie wird ein Unternehmen als mittelgroß eingestuft?',
#   'Category': '-Antragstellung',
#   'Document': 'fdee07ce'},
#  {'Question': 'Welche zusätzlichen Kriterien gelten neben der Mitarbeiterzahl für die KMU-Einstufung?',
#   'Category': '-Antragstellung',
#   'Document': 'fdee07ce'},
#  {'Question': 'Ab wann gilt ein Unternehmen nicht mehr als mittelgroß?',
#   'Category': '-Antragstellung',
#   'Document': 'fdee07ce'},
#  {'Question': 'Welche Rolle spielen Bilanzsumme und Umsatz bei der Einstufung als KMU?',
#   'Category': '-Antragstellung',
#   'Document': 'fdee07ce'},
#  {'Question': 'Ab wie vielen Mitarbeitern gilt ein Unternehmen nicht mehr als mittelgroßes Unternehmen?',
#   'Category': '-Antragstellung',
#   'Document': 'fdee07ce'},
#  {'Question': 'Welche Personen können mir bei der Antragsberatung helfen?',
#   'Category': '-Antragstellung',
#   'Document': '0435784a'},
#  {'Question': 'Wo finde ich die Ansprechpersonen für eine Antragsberatung?',
#   'Category': '-Antragstellung',
#   'Document': '0435784a'},
#  {'Question': 'Wer ist zuständig für Fragen zur Antragstellung?',
#   'Category': '-Antragstellung',
#   'Document': '0435784a'},
#  {'Question': 'Wen kann ich bezüglich Beratung zur Antragseinreichung kontaktieren?',
#   'Category': '-Antragstellung',
#   'Document': '0435784a'},
#  {'Question': 'An wen wende ich mich für Unterstützung bei meiner Antragstellung?',
#   'Category': '-Antragstellung',
#   'Document': '0435784a'},
#  {'Question': 'Wie hoch dürfen die Ausgaben für Gegenstände in der Position 0831 maximal sein?',
#   'Category': '-Antragstellung',
#   'Document': '9fca5d3f'},
#  {'Question': 'Wie viel Euro im Einzelfall können für Gegenstände in der Position 0831 beantragt werden?',
#   'Category': '-Antragstellung',
#   'Document': '9fca5d3f'},
#  {'Question': 'Welche maximale Summe gilt für die Abrechnung von Gegenständen in der Position 0831?',
#   'Category': '-Antragstellung',
#   'Document': '9fca5d3f'},
#  {'Question': 'Bis zu welchem Betrag sind Gegenstände in der Position 0831 abrechenbar?',
#   'Category': '-Antragstellung',
#   'Document': '9fca5d3f'},
#  {'Question': 'Was ist die Höchstgrenze für die Antragstellung von Gegenständen in der Position 0831?',
#   'Category': '-Antragstellung',
#   'Document': '9fca5d3f'},
#  {'Question': 'Warum könnten Projekttreffen im Ausland förderfähig sein?',
#   'Category': '-Antragstellung',
#   'Document': 'a781e3fa'},
#  {'Question': 'Welche Bedingungen müssen für die Förderfähigkeit von Auslandstreffen erfüllt sein?',
#   'Category': '-Antragstellung',
#   'Document': 'a781e3fa'},
#  {'Question': 'Sind Kosten für externe Personen bei Auslandstreffen förderfähig?',
#   'Category': '-Antragstellung',
#   'Document': 'a781e3fa'},
#  {'Question': 'Wer bekommt im Ausland gefördert, wenn es um Kosten oder Ausgaben geht?',
#   'Category': '-Antragstellung',
#   'Document': 'a781e3fa'},
#  {'Question': 'Was muss begründet werden, um Treffen im Ausland als förderfähig zu klassifizieren?',
#   'Category': '-Antragstellung',
#   'Document': 'a781e3fa'},
#  {'Question': 'Können mehrere Anträge von einer Rechtsperson gleichzeitig eingereicht werden?',
#   'Category': '-Antragstellung',
#   'Document': '1d52171f'},
#  {'Question': 'Müssen Personalkapazitäten bei mehreren Anträgen berücksichtigt werden?',
#   'Category': '-Antragstellung',
#   'Document': '1d52171f'},
#  {'Question': 'Welche Voraussetzungen müssen für parallele Projekte gegeben sein?',
#   'Category': '-Antragstellung',
#   'Document': '1d52171f'},
#  {'Question': 'Muss bei der Antragstellung bestätigt werden, dass das Projekt nicht anderweitig gefördert wird?',
#   'Category': '-Antragstellung',
#   'Document': '1d52171f'},
#  {'Question': 'Ist es erlaubt, Anträge zu unterschiedlichen Förderbekanntmachungen einzureichen?',
#   'Category': '-Antragstellung',
#   'Document': '1d52171f'},
#  {'Question': 'Darf ich das Formular online signieren und wie?',
#   'Category': '-Antragstellung',
#   'Document': '52a80020'},
#  {'Question': 'Welche Art von Signatur ist erforderlich, um das Formular online zu signieren?',
#   'Category': '-Antragstellung',
#   'Document': '52a80020'},
#  {'Question': 'Was benötige ich für die qualifizierte elektronische Signatur?',
#   'Category': '-Antragstellung',
#   'Document': '52a80020'},
#  {'Question': 'Wo finde ich die Software für das Kartenlesegerät?',
#   'Category': '-Antragstellung',
#   'Document': '52a80020'},
#  {'Question': 'Welches Trustcenter bietet eine geeignete Signaturkarte an?',
#   'Category': '-Antragstellung',
#   'Document': '52a80020'},
#  {'Question': 'Dürfen Personalausgaben, die aus öffentlichen Mitteln finanziert werden, über das Projekt abgerechnet werden?',
#   'Category': '-Antragstellung',
#   'Document': 'd8582fe4'},
#  {'Question': 'Können öffentlich finanzierte Mitarbeiter über die Projektmittel bezahlt werden?',
#   'Category': '-Antragstellung',
#   'Document': 'd8582fe4'},
#  {'Question': 'Ist es möglich, durch öffentliche Haushalte gedecktes Personal im Projekt zu finanzieren?',
#   'Category': '-Antragstellung',
#   'Document': 'd8582fe4'},
#  {'Question': 'Darf im Projekt Personal beantragt werden, das durch öffentliche Mittel finanziert wird?',
#   'Category': '-Antragstellung',
#   'Document': 'd8582fe4'},
#  {'Question': 'Können Personalkosten, die aus öffentlichen Haushalten stammen, im Projekt abgerechnet werden?',
#   'Category': '-Antragstellung',
#   'Document': 'd8582fe4'},
#  {'Question': 'Können Abschreibungskosten beantragt werden?',
#   'Category': '-Antragstellung',
#   'Document': 'ce22903e'},
#  {'Question': 'Wer kann Kosten für Abschreibungen beantragen?',
#   'Category': '-Antragstellung',
#   'Document': 'ce22903e'},
#  {'Question': 'Welche Anlagen dürfen abgeschrieben werden?',
#   'Category': '-Antragstellung',
#   'Document': 'ce22903e'},
#  {'Question': 'In welcher Position werden Abschreibungskosten beantragt?',
#   'Category': '-Antragstellung',
#   'Document': 'ce22903e'},
#  {'Question': 'Welche Bedingungen gelten für die anzusetzenden Investitionen?',
#   'Category': '-Antragstellung',
#   'Document': 'ce22903e'},
#  {'Question': 'Dürfen im Projekt Abschreibungen für spezifische Anlagen geltend gemacht werden?',
#   'Category': '-Antragstellung',
#   'Document': '14e76ae0'},
#  {'Question': 'Können Kosten für bereits vorhandene Anlagen im Vorhaben abgerechnet werden?',
#   'Category': '-Antragstellung',
#   'Document': '14e76ae0'},
#  {'Question': 'Welche Art von Anlagen können im Vorhaben abgeschrieben werden?',
#   'Category': '-Antragstellung',
#   'Document': '14e76ae0'},
#  {'Question': 'Von welcher Nutzungsdauer ist bei den Abschreibungen auszugehen?',
#   'Category': '-Antragstellung',
#   'Document': '14e76ae0'},
#  {'Question': 'Was gilt bei pauschalierter Abrechnung für Abschreibungen?',
#   'Category': '-Antragstellung',
#   'Document': '14e76ae0'},
#  {'Question': 'Können Stellenausschreibungskosten abgerechnet werden?',
#   'Category': '-Antragstellung',
#   'Document': '022f6af7'},
#  {'Question': 'Wie sollten Hochschulen Stellenausschreibungskosten decken?',
#   'Category': '-Antragstellung',
#   'Document': '022f6af7'},
#  {'Question': 'Dürfen Unternehmen Stellenausschreibungskosten abrechnen?',
#   'Category': '-Antragstellung',
#   'Document': '022f6af7'},
#  {'Question': 'Welche Kosten sind in den Gemeinkosten von Unternehmen enthalten?',
#   'Category': '-Antragstellung',
#   'Document': '022f6af7'},
#  {'Question': 'Sind Stellenausschreibungskosten förderbar?',
#   'Category': '-Antragstellung',
#   'Document': '022f6af7'},
#  {'Question': 'Sind Vorhabenbeschreibungen auf Englisch erlaubt?',
#   'Category': '-Antragstellung',
#   'Document': 'ba399d2d'},
#  {'Question': 'Wann können Projekte eine Ausnahme bilden?',
#   'Category': '-Antragstellung',
#   'Document': 'ba399d2d'},
#  {'Question': 'Müssen alle Vorhabenbeschreibungen auf Deutsch verfasst sein?',
#   'Category': '-Antragstellung',
#   'Document': 'ba399d2d'},
#  {'Question': 'Gibt es spezielle Fälle für englische Vorhabenbeschreibungen?',
#   'Category': '-Antragstellung',
#   'Document': 'ba399d2d'},
#  {'Question': 'Wo finde ich detaillierte Anforderungen zu den Ausnahmen?',
#   'Category': '-Antragstellung',
#   'Document': 'ba399d2d'},
#  {'Question': 'Was müssen wir tun, um Veranstaltungen, Schulungen oder Seminare abzurechnen?',
#   'Category': '-Antragstellung',
#   'Document': '926403f5'},
#  {'Question': 'Sind Kosten für Veranstaltungen, Schulungen oder Seminare automatisch bewilligt?',
#   'Category': '-Antragstellung',
#   'Document': '926403f5'},
#  {'Question': 'Wovon hängt es ab, ob Kosten für Veranstaltungen, Schulungen oder Seminare bewilligt werden?',
#   'Category': '-Antragstellung',
#   'Document': '926403f5'},
#  {'Question': 'Wie wird die Notwendigkeit von Schulungen oder Seminaren überprüft?',
#   'Category': '-Antragstellung',
#   'Document': '926403f5'},
#  {'Question': 'Wie hängt die Förderfähigkeit laut Bekanntmachung von den Kosten für Veranstaltungen, Schulungen oder Seminare ab?',
#   'Category': '-Antragstellung',
#   'Document': '926403f5'},
#  {'Question': 'Welche finanzielle Grenze gilt für Hotelübernachtungen?',
#   'Category': '-Antragstellung',
#   'Document': '7d85be84'},
#  {'Question': 'An welche Richtlinien kann ich mich bei Hotelkosten orientieren?',
#   'Category': '-Antragstellung',
#   'Document': '7d85be84'},
#  {'Question': 'Gibt es eine maximale Erstattung für Hotels?',
#   'Category': '-Antragstellung',
#   'Document': '7d85be84'},
#  {'Question': 'Welche Regelung gilt für Kosten bei Hotelaufenthalten?',
#   'Category': '-Antragstellung',
#   'Document': '7d85be84'},
#  {'Question': 'Wie wird die Obergrenze für Hotelkosten festgelegt?',
#   'Category': '-Antragstellung',
#   'Document': '7d85be84'},
#  {'Question': 'Gibt es eine Vorlage für die Geräteliste?',
#   'Category': '-Antragstellung',
#   'Document': '42acfab4'},
#  {'Question': 'Wer erstellt die Geräteliste?',
#   'Category': '-Antragstellung',
#   'Document': '42acfab4'},
#  {'Question': 'Auf welcher Basis wird die Geräteliste erstellt?',
#   'Category': '-Antragstellung',
#   'Document': '42acfab4'},
#  {'Question': 'Was ist die Geräteliste eine Anlage zu?',
#   'Category': '-Antragstellung',
#   'Document': '42acfab4'},
#  {'Question': 'Welche Firma erstellt die Geräteliste?',
#   'Category': '-Antragstellung',
#   'Document': '42acfab4'},
#  {'Question': 'Gibt es eine Vorlage für einen Teilantrag?',
#   'Category': '-Antragstellung',
#   'Document': 'e472e852'},
#  {'Question': 'Erhalte ich Informationen zur Antragstellung, wenn meine Skizze ausgewählt wird?',
#   'Category': '-Antragstellung',
#   'Document': 'e472e852'},
#  {'Question': 'Von wem erhalte ich die E-Mail zur Antragstellung?',
#   'Category': '-Antragstellung',
#   'Document': 'e472e852'},
#  {'Question': 'Wo finde ich den Link zur Antragstellung?',
#   'Category': '-Antragstellung',
#   'Document': 'e472e852'},
#  {'Question': 'In welchem System erfolgt die Antragstellung?',
#   'Category': '-Antragstellung',
#   'Document': 'e472e852'},
#  {'Question': 'Gibt es einen Höchstwert für Aufträge?',
#   'Category': '-Antragstellung',
#   'Document': 'ddad7cb2'},
#  {'Question': 'Muss das Verhältnis von Eigentätigkeit und Fremdleistung berücksichtigt werden?',
#   'Category': '-Antragstellung',
#   'Document': 'ddad7cb2'},
#  {'Question': 'Was ist erforderlich bei bestimmten Auftragssummen für FE-Aufträge?',
#   'Category': '-Antragstellung',
#   'Document': 'ddad7cb2'},
#  {'Question': 'Was bedeutet AAK bei FE-Aufträgen?',
#   'Category': '-Antragstellung',
#   'Document': 'ddad7cb2'},
#  {'Question': 'Was bedeutet AAA bei FE-Aufträgen?',
#   'Category': '-Antragstellung',
#   'Document': 'ddad7cb2'},
#  {'Question': 'Welche Höhe der Förderung gilt für KMU?',
#   'Category': '-Antragstellung',
#   'Document': 'c5030377'},
#  {'Question': 'Gibt es einen KMU Bonus?',
#   'Category': '-Antragstellung',
#   'Document': 'c5030377'},
#  {'Question': 'Wo finde ich Informationen zur Förderhöhe für KMU?',
#   'Category': '-Antragstellung',
#   'Document': 'c5030377'},
#  {'Question': 'Wie kann ich wissen, ob ein KMU Bonus berücksichtigt wird?',
#   'Category': '-Antragstellung',
#   'Document': 'c5030377'},
#  {'Question': 'Wohin sollte ich schauen, um die Förderhöhe für KMU zu erfahren?',
#   'Category': '-Antragstellung',
#   'Document': 'c5030377'},
#  {'Question': 'In welcher Position werden Geräte mit einem Anschaffungswert bis 800 Euro eingetragen?',
#   'Category': '-Antragstellung',
#   'Document': '701e340f'},
#  {'Question': 'In welcher Position werden Geräte mit einem Anschaffungswert über 800 Euro eingetragen?',
#   'Category': '-Antragstellung',
#   'Document': '701e340f'},
#  {'Question': 'Welchen Betrag darf ein Gerät nicht überschreiten, um in der Position 0850 eingetragen zu werden?',
#   'Category': '-Antragstellung',
#   'Document': '701e340f'},
#  {'Question': 'Ab welchem Anschaffungswert wird ein Gerät in der Position 0861 beantragt?',
#   'Category': '-Antragstellung',
#   'Document': '701e340f'},
#  {'Question': 'Müssen Geräte mit einem Anschaffungswert von genau 800 Euro in Position 0850 oder 0861 eingetragen werden?',
#   'Category': '-Antragstellung',
#   'Document': '701e340f'},
#  {'Question': 'Welche Position im Antrag muss ich für die Ausgaben für Publikationen nutzen?',
#   'Category': '-Antragstellung',
#   'Document': '7e2f62de'},
#  {'Question': 'Wie plane ich die Ausgaben für Publikationen im Antrag?',
#   'Category': '-Antragstellung',
#   'Document': '7e2f62de'},
#  {'Question': 'In welcher Position trägt man die Bezeichnung Publikationen ein?',
#   'Category': '-Antragstellung',
#   'Document': '7e2f62de'},
#  {'Question': 'Wo erfolgt die Abrechnung der Ausgaben für Publikationen?',
#   'Category': '-Antragstellung',
#   'Document': '7e2f62de'},
#  {'Question': 'Was deckt die Position 0843 im Antrag ab?',
#   'Category': '-Antragstellung',
#   'Document': '7e2f62de'},
#  {'Question': 'In welcher Position können Fortbildungen angesetzt werden?',
#   'Category': '-Antragstellung',
#   'Document': '608fe014'},
#  {'Question': 'Wer nimmt Aufgaben im Projekt wahr?',
#   'Category': '-Antragstellung',
#   'Document': '608fe014'},
#  {'Question': 'Sind assoziierte Partner gegenüber den Fördermittelgebern rechenschaftspflichtig?',
#   'Category': '-Antragstellung',
#   'Document': '608fe014'},
#  {'Question': 'Was stellt eine gute Option dar, um assoziierte Partner an das Konsortium zu binden?',
#   'Category': '-Antragstellung',
#   'Document': '608fe014'},
#  {'Question': 'Wie können assoziierte Partner:innen im Projekt eingebunden werden?',
#   'Category': '-Antragstellung',
#   'Document': '608fe014'},
#  {'Question': 'Dürfen Ausgaben für Mietwagen gefördert werden?',
#   'Category': '-Antragstellung',
#   'Document': '55398224'},
#  {'Question': 'Muss ich im Antrag darlegen, warum der Mietwagen notwendig ist?',
#   'Category': '-Antragstellung',
#   'Document': '55398224'},
#  {'Question': 'Für welche Zwecke darf der Mietwagen genutzt werden?',
#   'Category': '-Antragstellung',
#   'Document': '55398224'},
#  {'Question': 'Können Mietwagenkosten ohne Begründung zuwendungsfähig sein?',
#   'Category': '-Antragstellung',
#   'Document': '55398224'},
#  {'Question': 'Was muss im Antrag stehen, damit Mietwagenkosten akzeptiert werden?',
#   'Category': '-Antragstellung',
#   'Document': '55398224'},
#  {'Question': 'Kann die Projektpauschale für die IT-Infrastruktur verwendet werden?',
#   'Category': '-Antragstellung',
#   'Document': '93f470a0'},
#  {'Question': 'Wer entscheidet über die Nutzung der Projektpauschale?',
#   'Category': '-Antragstellung',
#   'Document': '93f470a0'},
#  {'Question': 'Deckt die Projektpauschale indirekte Ausgaben?',
#   'Category': '-Antragstellung',
#   'Document': '93f470a0'},
#  {'Question': 'Darf die Projektpauschale für Verwaltungspersonal genutzt werden?',
#   'Category': '-Antragstellung',
#   'Document': '93f470a0'},
#  {'Question': 'Ist die Überführung der Projektpauschale in den zentralen Haushalt notwendig?',
#   'Category': '-Antragstellung',
#   'Document': '93f470a0'},
#  {'Question': 'Ist Öffentlichkeitsarbeit generell förderfähig?',
#   'Category': '-Antragstellung',
#   'Document': 'c5a8a2e8'},
#  {'Question': 'Was muss bei der Antragstellung für Projekte mit öffentlichkeitswirksamen Aspekten beachtet werden?',
#   'Category': '-Antragstellung',
#   'Document': 'c5a8a2e8'},
#  {'Question': 'Kann die Öffentlichkeitsarbeit unter bestimmten Bedingungen fördern werden?',
#   'Category': '-Antragstellung',
#   'Document': 'c5a8a2e8'},
#  {'Question': 'Wer ist bei der Abstimmung der Öffentlichkeitsarbeit zu konsultieren?',
#   'Category': '-Antragstellung',
#   'Document': 'c5a8a2e8'},
#  {'Question': 'Gibt es spezifische Anforderungen für die förderfähige Öffentlichkeitsarbeit?',
#   'Category': '-Antragstellung',
#   'Document': 'c5a8a2e8'},
#  {'Question': 'Dürfen wir den pdf-Antrag nach Einreichung noch ändern?',
#   'Category': '-Antragstellung',
#   'Document': '5d868998'},
#  {'Question': 'Wie können wir kleine Änderungen am Antrag vornehmen?',
#   'Category': '-Antragstellung',
#   'Document': '5d868998'},
#  {'Question': 'Was ist zu tun, wenn Änderungen bei Zahlungsanforderungen nötig sind?',
#   'Category': '-Antragstellung',
#   'Document': '5d868998'},
#  {'Question': 'Kann man die Endfassung des Antrags nachträglich handschriftlich bearbeiten?',
#   'Category': '-Antragstellung',
#   'Document': '5d868998'},
#  {'Question': 'Wie verfahren wir mit Änderungen bei Zwischennachweisen?',
#   'Category': '-Antragstellung',
#   'Document': '5d868998'},
#  {'Question': 'Ist ein Antrag nötig, wenn Position 0817 um 15% überschritten wird?',
#   'Category': '-Antragstellung',
#   'Document': 'f2d3130b'},
#  {'Question': 'Was muss eingereicht werden, wenn Position 0817 um mehr als 20% überschritten wird?',
#   'Category': '-Antragstellung',
#   'Document': 'f2d3130b'},
#  {'Question': 'Was bedeutet es, dass Mittelumwidmungen zuwendungsneutral erfolgen müssen?',
#   'Category': '-Antragstellung',
#   'Document': 'f2d3130b'},
#  {'Question': 'Wie werden die Zuwendungsempfänger über das Ergebnis des Mittelumwidmungsantrages informiert?',
#   'Category': '-Antragstellung',
#   'Document': 'f2d3130b'},
#  {'Question': 'Kann eine Position ohne Antrag überschritten werden, wenn es sich um Personalausgaben handelt?',
#   'Category': '-Antragstellung',
#   'Document': 'f2d3130b'},
#  {'Question': 'Ist die digitale Signatur beim Easy-Online Formular zwingend erforderlich?',
#   'Category': '-Antragstellung',
#   'Document': '38f20c19'},
#  {'Question': 'Kann ich das Easy-Online Formular nur online abschicken?',
#   'Category': '-Antragstellung',
#   'Document': '38f20c19'},
#  {'Question': 'Müssen bei der Einreichung im Easy-Online Portal alle Formulare elektronisch signiert sein?',
#   'Category': '-Antragstellung',
#   'Document': '38f20c19'},
#  {'Question': 'Gibt es eine Möglichkeit, das Easy-Online Formular ohne Signatur zu versenden?',
#   'Category': '-Antragstellung',
#   'Document': '38f20c19'},
#  {'Question': 'Welches Verfahren kann ich im Easy-Online Portal wählen, wenn ich keine elektronische Signatur habe?',
#   'Category': '-Antragstellung',
#   'Document': '38f20c19'},
#  {'Question': 'Kann man die Arbeitszeit in einem Förderprojekt teilweise angeben?',
#   'Category': '-Antragstellung',
#   'Document': '4701d420'},
#  {'Question': 'Muss das Förderprojekt im Arbeitsvertrag namentlich erwähnt werden?',
#   'Category': '-Antragstellung',
#   'Document': '4701d420'},
#  {'Question': 'Wird der Umfang der Arbeit im Projekt in Prozent genannt, wenn die Arbeit nicht 100 % der Zeit geplant ist?',
#   'Category': '-Antragstellung',
#   'Document': '4701d420'},
#  {'Question': 'Gilt diese Regelung zur Arbeitszeitangabe für Hochschulen?',
#   'Category': '-Antragstellung',
#   'Document': '4701d420'},
#  {'Question': 'Braucht man einen Zusatz zum Arbeitsvertrag, um die Arbeitszeit im Projekt anzugeben?',
#   'Category': '-Antragstellung',
#   'Document': '4701d420'},
#  {'Question': 'Sind administrativ tätige Mitarbeiter im Projekt abrechenbar?',
#   'Category': '-Antragstellung',
#   'Document': 'c19e31eb'},
#  {'Question': 'Sind administrative Tätigkeiten im Projekt zuwendungsfähig?',
#   'Category': '-Antragstellung',
#   'Document': 'c19e31eb'},
#  {'Question': 'Werden administrative Tätigkeiten im Projekt finanziert?',
#   'Category': '-Antragstellung',
#   'Document': 'c19e31eb'},
#  {'Question': 'Wie werden administrative Tätigkeiten für Hochschulen im Projekt abgegolten?',
#   'Category': '-Antragstellung',
#   'Document': 'c19e31eb'},
#  {'Question': 'Sind administrative Kosten für Unternehmen im Projekt enthalten?',
#   'Category': '-Antragstellung',
#   'Document': 'c19e31eb'},
#  {'Question': 'Welche Voraussetzung müssen ausländische Partner erfüllen, um als assoziierte Partner ohne Förderung teilzunehmen?',
#   'Category': '-Antragstellung',
#   'Document': '9bded725'},
#  {'Question': 'Muss ein Unternehmen eine Niederlassung in Deutschland haben, um antragsberechtigt zu sein?',
#   'Category': '-Antragstellung',
#   'Document': '9bded725'},
#  {'Question': 'Können ausländische Partner über einen Unterauftrag eingebunden werden?',
#   'Category': '-Antragstellung',
#   'Document': '9bded725'},
#  {'Question': 'Welche Bedingungen müssen ausländische Partner erfüllen, um einen Mehrwert für das Verbundprojekt zu erbringen?',
#   'Category': '-Antragstellung',
#   'Document': '9bded725'},
#  {'Question': 'Wo finde ich die genauen Details zur Antragsberechtigung?',
#   'Category': '-Antragstellung',
#   'Document': '9bded725'},
#  {'Question': 'Dürfen Mitarbeitende an Hochschulen in mehreren Projekten tätig sein und wie wird das dokumentiert?',
#   'Category': '-Antragstellung',
#   'Document': 'be61582b'},
#  {'Question': 'Wie wird die Abrechnung für Hochschulmitarbeitende geregelt, die in mehreren Projekten arbeiten?',
#   'Category': '-Antragstellung',
#   'Document': 'be61582b'},
#  {'Question': 'Welche Bedingungen gelten für Mitarbeitende von Industrieunternehmen, die in mehreren Projekten aktiv sind?',
#   'Category': '-Antragstellung',
#   'Document': 'be61582b'},
#  {'Question': 'Wie erfolgt die Abrechnung von Stunden für Industrieunternehmen in verschiedenen Projekten?',
#   'Category': '-Antragstellung',
#   'Document': 'be61582b'},
#  {'Question': 'Welche Dokumentation ist erforderlich, damit Mitarbeitende an Hochschulen in mehreren Projekten arbeiten dürfen?',
#   'Category': '-Antragstellung',
#   'Document': 'be61582b'},
#  {'Question': 'Ist eine TVB bei Einzelvorhaben immer erforderlich?',
#   'Category': '-Antragstellung',
#   'Document': 'c9673fcf'},
#  {'Question': 'Kann auf eine spezielle TVB bei sehr kleinen Verbünden verzichtet werden?',
#   'Category': '-Antragstellung',
#   'Document': 'c9673fcf'},
#  {'Question': 'Benötigt man für Einzelvorhaben und kleine Verbünde immer eine TVB?',
#   'Category': '-Antragstellung',
#   'Document': 'c9673fcf'},
#  {'Question': 'Gibt es Umstände, unter denen keine TVB bei der Antragstellung notwendig ist?',
#   'Category': '-Antragstellung',
#   'Document': 'c9673fcf'},
#  {'Question': 'Wann kann die TVB bei der Antragstellung weggelassen werden?',
#   'Category': '-Antragstellung',
#   'Document': 'c9673fcf'},
#  {'Question': 'Wer finanziert die Reisekosten der assoziierten Partner?',
#   'Category': '-Antragstellung',
#   'Document': 'a26133f3'},
#  {'Question': 'Muss der Projektkoordinator für die Reisekosten der assoziierten Partner aufkommen?',
#   'Category': '-Antragstellung',
#   'Document': 'a26133f3'},
#  {'Question': 'Übernimmt jemand anderes die Reisekosten der assoziierten Partner?',
#   'Category': '-Antragstellung',
#   'Document': 'a26133f3'},
#  {'Question': 'Müssen die assoziierten Partner ihre Reisekosten selbst tragen?',
#   'Category': '-Antragstellung',
#   'Document': 'a26133f3'},
#  {'Question': 'Wer trägt die Kosten für die Reisen der assoziierten Partner?',
#   'Category': '-Antragstellung',
#   'Document': 'a26133f3'},
#  {'Question': 'Muss die Projektskizze unterschrieben sein?',
#   'Category': '-Antragstellung',
#   'Document': '98c8c787'},
#  {'Question': 'Ist die Projektskizze ein formaler Förderantrag?',
#   'Category': '-Antragstellung',
#   'Document': '98c8c787'},
#  {'Question': 'Wie reiche ich die Projektskizze digital ein?',
#   'Category': '-Antragstellung',
#   'Document': '98c8c787'},
#  {'Question': 'Wo finde ich den Link zum Online-Skizzentool?',
#   'Category': '-Antragstellung',
#   'Document': '98c8c787'},
#  {'Question': 'Erhalte ich eine Bestätigung nach der Einreichung der Projektskizze?',
#   'Category': '-Antragstellung',
#   'Document': '98c8c787'},
#  {'Question': 'Müssen Antragsteller:innen in Deutschland ansässig sein oder genügt eine Niederlassung?',
#   'Category': '-Antragstellung',
#   'Document': '2e168ea2'},
#  {'Question': 'Wie werden Unternehmen im ausländischen Mehrheitsbesitz antragsberechtigt?',
#   'Category': '-Antragstellung',
#   'Document': '2e168ea2'},
#  {'Question': 'Ist eine Betriebsstätte in Deutschland immer erforderlich für eine Antragsberechtigung?',
#   'Category': '-Antragstellung',
#   'Document': '2e168ea2'},
#  {'Question': 'Welche Kriterien müssen erfüllt sein, damit der Verwertungsplan als realistisch erscheint?',
#   'Category': '-Antragstellung',
#   'Document': '2e168ea2'},
#  {'Question': 'Welche Maßnahmen müssen vorgesehen werden, um einen unerwünschten Know-how-Abfluss zu verhindern?',
#   'Category': '-Antragstellung',
#   'Document': '2e168ea2'},
#  {'Question': 'Müssen Teilnehmende eines Verbundprojekts eine Kooperationsvereinbarung schriftlich festhalten?',
#   'Category': '-Antragstellung',
#   'Document': 'fd3852f6'},
#  {'Question': 'Gibt es ein vorgegebenes Vertragsmuster für die Kooperationsvereinbarung der Partner:innen?',
#   'Category': '-Antragstellung',
#   'Document': 'fd3852f6'},
#  {'Question': 'Was muss aus der schriftlichen Kooperationsvereinbarung der Partner:innen hervorgehen?',
#   'Category': '-Antragstellung',
#   'Document': 'fd3852f6'},
#  {'Question': 'Welche Aspekte soll die Kooperationsvereinbarung beinhalten?',
#   'Category': '-Antragstellung',
#   'Document': 'fd3852f6'},
#  {'Question': 'Wo kann ich weitere Informationen zur Kooperationsvereinbarung finden?',
#   'Category': '-Antragstellung',
#   'Document': 'fd3852f6'},
#  {'Question': 'Welche Abrechnungsart ist derzeit nur mit Einschränkungen möglich?',
#   'Category': '-Antragstellung',
#   'Document': '1c0bedbd'},
#  {'Question': 'Warum ist die pauschalierte Abrechnung bei Neubewilligung nicht mehr möglich?',
#   'Category': '-Antragstellung',
#   'Document': '1c0bedbd'},
#  {'Question': 'Welche Alternativen gibt es zur pauschalierten Abrechnung?',
#   'Category': '-Antragstellung',
#   'Document': '1c0bedbd'},
#  {'Question': 'Was sollte man tun, wenn man Fragen zur Abrechnung hat?',
#   'Category': '-Antragstellung',
#   'Document': '1c0bedbd'},
#  {'Question': 'An wen sollte man sich bei Fragen zur Abrechnung wenden?',
#   'Category': '-Antragstellung',
#   'Document': '1c0bedbd'},
#  {'Question': 'Können Kosten, die durch den Prozess der Antragstellung entstehen, gefördert werden?',
#   'Category': '-Antragstellung',
#   'Document': '9b824412'},
#  {'Question': 'Sind Kosten, die vor dem Laufzeitbeginn des Vorhabens entstehen, zuwendungsfähig?',
#   'Category': '-Antragstellung',
#   'Document': '9b824412'},
#  {'Question': 'Werden die durch die Antragstellung verursachten Ausgaben erstattet?',
#   'Category': '-Antragstellung',
#   'Document': '9b824412'},
#  {'Question': 'Sind die Kosten, die vor Beginn des Vorhabens liegen, förderfähig?',
#   'Category': '-Antragstellung',
#   'Document': '9b824412'},
#  {'Question': 'Kann ich Kosten, die durch das Einreichen eines Förderantrags anfallen, erstattet bekommen?',
#   'Category': '-Antragstellung',
#   'Document': '9b824412'},
#  {'Question': 'Welche Kosten sind zu berücksichtigen, Brutto oder Netto?',
#   'Category': '-Antragstellung',
#   'Document': '4c934734'},
#  {'Question': 'Wie sollen Beträge angesetzt werden, wenn keine Vorsteuerabzugsberechtigung besteht?',
#   'Category': '-Antragstellung',
#   'Document': '4c934734'},
#  {'Question': 'Ist die Mehrwertsteuer bei Vorsteuerabzugsberechtigung abzurechnen?',
#   'Category': '-Antragstellung',
#   'Document': '4c934734'},
#  {'Question': 'Müssen Skonti und Rabatte abgezogen werden, wenn sie nicht in Anspruch genommen werden?',
#   'Category': '-Antragstellung',
#   'Document': '4c934734'},
#  {'Question': 'Kann die Mehrwertsteuer beantragt werden, wenn der Empfänger zum Vorsteuerabzug berechtigt ist?',
#   'Category': '-Antragstellung',
#   'Document': '4c934734'},
#  {'Question': 'Sind die Kosten für qualifizierte Signaturen förderfähig?',
#   'Category': '-Antragstellung',
#   'Document': 'b403f96e'},
#  {'Question': 'Werden die Einrichtungsgebühren für qualifizierte Signaturen abgedeckt?',
#   'Category': '-Antragstellung',
#   'Document': 'b403f96e'},
#  {'Question': 'Sind Ausgaben für die Anwendung von qualifizierten Signaturen förderfähig?',
#   'Category': '-Antragstellung',
#   'Document': 'b403f96e'},
#  {'Question': 'Decken die Fördermittel die Nutzung von qualifizierten Signaturen?',
#   'Category': '-Antragstellung',
#   'Document': 'b403f96e'},
#  {'Question': 'Sind die Kosten für die Einrichtung von qualifizierten Signaturen förderfähig?',
#   'Category': '-Antragstellung',
#   'Document': 'b403f96e'},
#  {'Question': 'Sind Website-Ausgaben förderfähig?',
#   'Category': '-Antragstellung',
#   'Document': 'b1357fd2'},
#  {'Question': 'Sind Social Media Kosten bewilligungsfähig?',
#   'Category': '-Antragstellung',
#   'Document': 'b1357fd2'},
#  {'Question': 'Können Blog-Kosten erstattet werden?',
#   'Category': '-Antragstellung',
#   'Document': 'b1357fd2'},
#  {'Question': 'Gibt es Förderungen für Webseiten?',
#   'Category': '-Antragstellung',
#   'Document': 'b1357fd2'},
#  {'Question': 'Werden wissenschaftliche Kommunikation-Websites gefördert?',
#   'Category': '-Antragstellung',
#   'Document': 'b1357fd2'},
#  {'Question': 'Wird die Finanzierung von Veröffentlichungskosten unterstützt?',
#   'Category': '-Antragstellung',
#   'Document': '251061cf'},
#  {'Question': 'Sind die Kosten für Veröffentlichungen im Projekt abdeckbar?',
#   'Category': '-Antragstellung',
#   'Document': '251061cf'},
#  {'Question': 'Decken Fördermittel die Kosten für Publikationen?',
#   'Category': '-Antragstellung',
#   'Document': '251061cf'},
#  {'Question': 'Können Publikationskosten aus Fördermitteln bezahlt werden?',
#   'Category': '-Antragstellung',
#   'Document': '251061cf'},
#  {'Question': 'Brauche ich eigene Mittel für Publikationen?',
#   'Category': '-Antragstellung',
#   'Document': '251061cf'},
#  {'Question': 'Muss man die Anzahl der Beschäftigten als Vollzeitäquivalente angeben?',
#   'Category': '-Antragstellung',
#   'Document': '39afe07d'},
#  {'Question': 'Wie viele Beschäftigte entsprechen zwei Personen mit je 50% Stellen?',
#   'Category': '-Antragstellung',
#   'Document': '39afe07d'},
#  {'Question': 'Wie betrachtet man die Anzahl der Beschäftigten bei der KMU Status-Prüfung?',
#   'Category': '-Antragstellung',
#   'Document': '39afe07d'},
#  {'Question': 'Was ist ein Vollzeitäquivalent bei der Antragstellung?',
#   'Category': '-Antragstellung',
#   'Document': '39afe07d'},
#  {'Question': 'Wie gibt man die Anzahl Teilzeitbeschäftigter bei der KMU Prüfung an?',
#   'Category': '-Antragstellung',
#   'Document': '39afe07d'},
#  {'Question': 'Können gemeinnützige Vereine Fördergelder beantragen?',
#   'Category': '-Antragstellung',
#   'Document': '6fb7d823'},
#  {'Question': 'Ist es gemeinnützigen Organisationen erlaubt, Fördergelder zu beantragen?',
#   'Category': '-Antragstellung',
#   'Document': '6fb7d823'},
#  {'Question': 'Darf jeder gemeinnützige Verein Fördergelder beantragen?',
#   'Category': '-Antragstellung',
#   'Document': '6fb7d823'},
#  {'Question': 'Sind gemeinnützige Vereine berechtigt, Fördermittel zu beantragen?',
#   'Category': '-Antragstellung',
#   'Document': '6fb7d823'},
#  {'Question': 'Können Organisationen mit Gemeinnützigkeit Fördergelder anfordern?',
#   'Category': '-Antragstellung',
#   'Document': '6fb7d823'},
#  {'Question': 'Welche Bedingung muss erfüllt sein, um mit Partnern aus dem europäischen Ausland zusammenzuarbeiten?',
#   'Category': '-Antragstellung',
#   'Document': '5d63cd3a'},
#  {'Question': 'Wie kann ein unersetzlicher Mehrwert durch ausländische Partner nachgewiesen werden?',
#   'Category': '-Antragstellung',
#   'Document': '5d63cd3a'},
#  {'Question': 'Was muss ein ausländischer Kooperationspartner bieten, damit eine Zusammenarbeit möglich ist?',
#   'Category': '-Antragstellung',
#   'Document': '5d63cd3a'},
#  {'Question': 'Kann ich mit einem Partner aus dem europäischen Ausland zusammenarbeiten, wenn sein Mehrwert auch von einem anderen Partner geleistet werden könnte?',
#   'Category': '-Antragstellung',
#   'Document': '5d63cd3a'},
#  {'Question': 'Welche Voraussetzungen müssen erfüllt sein, um ausländische Kooperationspartner einzubinden?',
#   'Category': '-Antragstellung',
#   'Document': '5d63cd3a'},
#  {'Question': 'Wann dürfen Bestellvorgänge und Arbeiten im Rahmen des Projektes begonnen werden?',
#   'Category': '-Antragstellung',
#   'Document': 'b03c4bd9'},
#  {'Question': 'Mit wem muss der Start des Fördervorhabens abgestimmt werden?',
#   'Category': '-Antragstellung',
#   'Document': 'b03c4bd9'},
#  {'Question': 'Was müssen Antragstellende im Antragsformular bestätigen?',
#   'Category': '-Antragstellung',
#   'Document': 'b03c4bd9'},
#  {'Question': 'Wann beginnt die Laufzeit eines Fördervorhabens?',
#   'Category': '-Antragstellung',
#   'Document': 'b03c4bd9'},
#  {'Question': 'Wer bestimmt den möglichen Start eines Fördervorhabens?',
#   'Category': '-Antragstellung',
#   'Document': 'b03c4bd9'},
#  {'Question': 'Wann kann die erste Zahlungsanforderung für Projekte auf Ausgabenbasis eingereicht werden?',
#   'Category': '-Antragstellung',
#   'Document': '76444279'},
#  {'Question': 'Wann kann die erste Zahlungsanforderung für Projekte auf Kostenbasis gestellt werden?',
#   'Category': '-Antragstellung',
#   'Document': '76444279'},
#  {'Question': 'Welche Projekte dürfen ihre Schätzausgaben für die nächsten 6 Wochen abrechnen?',
#   'Category': '-Antragstellung',
#   'Document': '76444279'},
#  {'Question': 'In welchem Monat kann die erste Zahlungsanforderung im neuen Kalenderjahr eingereicht werden?',
#   'Category': '-Antragstellung',
#   'Document': '76444279'},
#  {'Question': 'Wie oft können bei Projekten auf Kostenbasis die Kosten abgerechnet werden?',
#   'Category': '-Antragstellung',
#   'Document': '76444279'},
#  {'Question': 'Welche Angaben müssen beim ersten Finanzierungsplan gemacht werden?',
#   'Category': '-Antragstellung',
#   'Document': '8a04b89e'},
#  {'Question': 'Wann muss eine erste Kostenabschätzung erfolgen?',
#   'Category': '-Antragstellung',
#   'Document': '8a04b89e'},
#  {'Question': 'Wer stellt die erste Abschätzung der Projektkosten bereit?',
#   'Category': '-Antragstellung',
#   'Document': '8a04b89e'},
#  {'Question': 'Wie erfolgt die detaillierte Kalkulation der Projektkosten?',
#   'Category': '-Antragstellung',
#   'Document': '8a04b89e'},
#  {'Question': 'Über welches Portal wird der Antrag mit den detaillierten Kalkulationen eingereicht?',
#   'Category': '-Antragstellung',
#   'Document': '8a04b89e'},
#  {'Question': 'Können Bruttoausgaben anerkannt werden, wenn keine Vorsteuerabzugsberechtigung vorliegt?',
#   'Category': '-Antragstellung',
#   'Document': '31554379'},
#  {'Question': 'Müssen Nettopreise beantragt und abgerechnet werden, wenn eine Vorsteuerabzugsberechtigung vorliegt?',
#   'Category': '-Antragstellung',
#   'Document': '31554379'},
#  {'Question': 'Was passiert, wenn keine Vorsteuerabzugsberechtigung besteht?',
#   'Category': '-Antragstellung',
#   'Document': '31554379'},
#  {'Question': 'Welche Preise sind förderfähig, wenn die Vorsteuerabzugsberechtigung gegeben ist?',
#   'Category': '-Antragstellung',
#   'Document': '31554379'},
#  {'Question': 'Wovon hängt es ab, ob Brutto- und Nettoausgaben im Projekt anerkannt werden können?',
#   'Category': '-Antragstellung',
#   'Document': '31554379'},
#  {'Question': 'Warum führt eine dritte Firma den Verwendungsnachweis durch?',
#   'Category': '-Antragstellung',
#   'Document': '67d20eeb'},
#  {'Question': 'Wer ist für die Prüfung des Verwendungsnachweises zuständig?',
#   'Category': '-Antragstellung',
#   'Document': '67d20eeb'},
#  {'Question': 'Welche Firma unterstützt die Prüfung der Verwendungsnachweise?',
#   'Category': '-Antragstellung',
#   'Document': '67d20eeb'},
#  {'Question': 'Was ist die Beziehung zwischen FILINA Innovation + Technik GmbH und VDI/VDE Innovation + Technik GmbH?',
#   'Category': '-Antragstellung',
#   'Document': '67d20eeb'},
#  {'Question': 'Warum hilft die FILINA GmbH bei den Prüfaufgaben?',
#   'Category': '-Antragstellung',
#   'Document': '67d20eeb'},
#  {'Question': 'Warum ist die Mittelbereitstellung häufig nicht entsprechend des Antrags?',
#   'Category': '-Antragstellung',
#   'Document': 'fc308a5f'},
#  {'Question': 'Wie oft wird geprüft, ob die Mittelbereitstellung dem tatsächlichen Bedarf entspricht?',
#   'Category': '-Antragstellung',
#   'Document': 'fc308a5f'},
#  {'Question': 'Was passiert, wenn die jährliche Bereitstellung nicht dem tatsächlichen Bedarf entspricht?',
#   'Category': '-Antragstellung',
#   'Document': 'fc308a5f'},
#  {'Question': 'Welche Faktoren beeinflussen den Erstbescheid zur Mittelbereitstellung?',
#   'Category': '-Antragstellung',
#   'Document': 'fc308a5f'},
#  {'Question': 'Gibt es Möglichkeiten, die Mittelbereitstellung anzupassen, wenn der Bedarf anders ist?',
#   'Category': '-Antragstellung',
#   'Document': 'fc308a5f'},
#  {'Question': 'Was ist die pauschalierte Abrechnung?',
#   'Category': '-Antragstellung',
#   'Document': '24193782'},
#  {'Question': 'Welche Basis hat die pauschalierte Abrechnung?',
#   'Category': '-Antragstellung',
#   'Document': '24193782'},
#  {'Question': 'Wann kann ich pauschaliert abrechnen?',
#   'Category': '-Antragstellung',
#   'Document': '24193782'},
#  {'Question': 'Was muss ich erfüllen, um pauschaliert abzurechnen?',
#   'Category': '-Antragstellung',
#   'Document': '24193782'},
#  {'Question': 'Wofür vereinfacht die pauschalierte Abrechnung die Prozesse?',
#   'Category': '-Antragstellung',
#   'Document': '24193782'},
#  {'Question': 'Was passiert mit einem Antragsteller nach erfolgreicher Prüfung des Antrages?',
#   'Category': '-Antragstellung',
#   'Document': 'afdab58a'},
#  {'Question': 'Wer sind die Vertragspartner eines Antragstellers?',
#   'Category': '-Antragstellung',
#   'Document': 'afdab58a'},
#  {'Question': 'Erhalten die Vertragspartner Zuwendungen?',
#   'Category': '-Antragstellung',
#   'Document': 'afdab58a'},
#  {'Question': 'Wer wird nach erfolgreicher Antragsprüfung zu Zuwendungsempfängern?',
#   'Category': '-Antragstellung',
#   'Document': 'afdab58a'},
#  {'Question': 'Können Unterauftragnehmer des Antragstellers Zuwendungen bekommen?',
#   'Category': '-Antragstellung',
#   'Document': 'afdab58a'},
#  {'Question': 'Was bedeutet AGVO?',
#   'Category': '-Antragstellung',
#   'Document': '27b7b443'},
#  {'Question': 'Was regelt die Allgemeine Gruppenfreistellungsverordnung?',
#   'Category': '-Antragstellung',
#   'Document': '27b7b443'},
#  {'Question': 'Wofür steht AGVO?',
#   'Category': '-Antragstellung',
#   'Document': '27b7b443'},
#  {'Question': 'Welche Maßnahmen können laut AGVO umgesetzt werden?',
#   'Category': '-Antragstellung',
#   'Document': '27b7b443'},
#  {'Question': 'Braucht es eine Genehmigung der Europäischen Kommission für Maßnahmen unter AGVO?',
#   'Category': '-Antragstellung',
#   'Document': '27b7b443'},
#  {'Question': 'Wo finde ich die Höchstgrenze der Zuwendung?',
#   'Category': '-Antragstellung',
#   'Document': '7632767b'},
#  {'Question': 'Wie wird die Höhe der Zuwendung festgelegt?',
#   'Category': '-Antragstellung',
#   'Document': '7632767b'},
#  {'Question': 'Gibt es eine Begrenzung der Zuwendung für KMU Innovativ?',
#   'Category': '-Antragstellung',
#   'Document': '7632767b'},
#  {'Question': 'Was passiert, wenn keine Einschränkung der Zuwendung genannt wird?',
#   'Category': '-Antragstellung',
#   'Document': '7632767b'},
#  {'Question': 'Wie werden die Anträge beurteilt, wenn keine Zuwendungshöhe festgelegt ist?',
#   'Category': '-Antragstellung',
#   'Document': '7632767b'},
#  {'Question': 'Was ist mit N.N.-Personal gemeint?',
#   'Category': '-Antragstellung',
#   'Document': 'c841f0a6'},
#  {'Question': 'Wie wird Personal bezeichnet, das im Antrag namentlich nicht bekannt ist?',
#   'Category': '-Antragstellung',
#   'Document': 'c841f0a6'},
#  {'Question': 'Was bedeutet es, wenn jemand im Antrag als namentlich nicht bekannt angegeben wird?',
#   'Category': '-Antragstellung',
#   'Document': 'c841f0a6'},
#  {'Question': 'Was versteht man im Kontext der Antragstellung unter N.N. Stelle?',
#   'Category': '-Antragstellung',
#   'Document': 'c841f0a6'},
#  {'Question': 'Welche Information muss angegeben werden, wenn das beantragte Personal noch nicht namentlich bekannt ist?',
#   'Category': '-Antragstellung',
#   'Document': 'c841f0a6'},
#  {'Question': 'Wenn ich keinen Kooperationsvertrag bei der Antragstellung vorweisen kann, was geschieht dann?',
#   'Category': '-Antragstellung',
#   'Document': '43605403'},
#  {'Question': 'Welche Maßnahmen müssen ergriffen werden, wenn die Kooperationsvereinbarung bei der Antragstellung fehlt?',
#   'Category': '-Antragstellung',
#   'Document': '43605403'},
#  {'Question': 'Bis wann müssen alle Partner die schriftliche Kooperationsvereinbarung unterschreiben, wenn sie bei der Antragstellung nicht vorliegt?',
#   'Category': '-Antragstellung',
#   'Document': '43605403'},
#  {'Question': 'Wo finde ich Hinweise zu den notwendigen Inhalten eines Kooperationsvertrages bei Verbundprojekten?',
#   'Category': '-Antragstellung',
#   'Document': '43605403'},
#  {'Question': 'Was regelt die schriftliche Kooperationsvereinbarung in einem Verbundprojekt?',
#   'Category': '-Antragstellung',
#   'Document': '43605403'},
#  {'Question': 'Welche Unterstützung gibt es, wenn mein Projekt nicht zur Fördermaßnahme passt?',
#   'Category': '-Antragstellung',
#   'Document': '79a20ee6'},
#  {'Question': 'Wie kann ich die Förderberatung des Bundes kontaktieren?',
#   'Category': '-Antragstellung',
#   'Document': '79a20ee6'},
#  {'Question': 'Wo finde ich Informationen zur Förderberatung des Bundes online?',
#   'Category': '-Antragstellung',
#   'Document': '79a20ee6'},
#  {'Question': 'Gibt es eine gebührenfreie Telefonnummer für die Forschungsförderung?',
#   'Category': '-Antragstellung',
#   'Document': '79a20ee6'},
#  {'Question': 'Kann ich die Förderberatung des Bundes per E-Mail erreichen?',
#   'Category': '-Antragstellung',
#   'Document': '79a20ee6'},
#  {'Question': 'Was sind Kosten, die sich keinem spezifischen Kostenträger oder einer Kostenstelle im Unternehmen zuordnen lassen?',
#   'Category': '-Antragstellung',
#   'Document': 'e69f65be'},
# ...
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': '5417f011'},
#  {'Question': 'Wer erhält im Falle von Verbundprojekten die Information über das Ergebnis der Skizzenauswahl?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': '5ea0e444'},
#  {'Question': 'Auf welchem Weg werden die Skizzeneinreichenden über das Ergebnis der Skizzenauswahl informiert?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': '5ea0e444'},
#  {'Question': 'Bekommen nur Koordinatoren im Falle von Verbundprojekten die Mitteilung über das Ergebnis der Skizzenauswahl?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': '5ea0e444'},
#  {'Question': 'Erhalten die Skizzeneinreichenden per Post oder E-Mail eine Zusage zur Förderung oder eine Absage?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': '5ea0e444'},
#  {'Question': 'Wer bekommt eine E-Mail mit der Entscheidung über die Förderung bei einer Skizzeneinreichung?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': '5ea0e444'},
#  {'Question': 'Wo finde ich die richtige Vorlage zur Teilvorhabenbeschreibung?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': 'b675d6bf'},
#  {'Question': 'Welche Teilvorhabenbeschreibung muss ich für AZK verwenden?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': 'b675d6bf'},
#  {'Question': 'Braucht AZK eine spezielle Teilvorhabenbeschreibung?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': 'b675d6bf'},
#  {'Question': 'Welche Dokumentation ist für die Beantragung auf Kostenbasis notwendig?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': 'b675d6bf'},
#  {'Question': 'Gibt es unterschiedliche Vorlagen für AZK und AZA?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': 'b675d6bf'},
#  {'Question': 'Wo finde ich Informationen zu geförderten Projekten?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': 'b8c9f17c'},
#  {'Question': 'Gibt es eine zentrale Liste mit allen aktuellen BMBF Projekten?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': 'b8c9f17c'},
#  {'Question': 'Wo kann ich aktuelle BMBF Projekte recherchieren?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': 'b8c9f17c'},
#  {'Question': 'Welche Seite zeigt alle derzeit unterstützten BMBF Projekte?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': 'b8c9f17c'},
#  {'Question': 'Wo finde ich eine Übersicht der gegenwärtig vom BMBF finanzierten Projekte?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': 'b8c9f17c'},
#  {'Question': 'Wo finde ich den Formularschrank?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': '8918064c'},
#  {'Question': 'Wo befindet sich der Formularschrank?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': '8918064c'},
#  {'Question': 'Unter welchem Link finde ich den Formularschrank?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': '8918064c'},
#  {'Question': 'Wie erreiche ich den Formularschrank online?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': '8918064c'},
#  {'Question': 'Wo genau ist der Formularschrank zu finden?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': '8918064c'},
#  {'Question': 'Wo erfolgt die Skizzeneinreichung im Antragsverfahren?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': '8754681e'},
#  {'Question': 'Was ist der erste Schritt im mehrstufigen Antragsverfahren?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': '8754681e'},
#  {'Question': 'Wo finde ich den Link zur Skizzeneinreichung für den Antrag?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': '8754681e'},
#  {'Question': 'Welche Information benötige ich zur Einreichung der ersten Stufe des Antrages?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': '8754681e'},
#  {'Question': 'Was ist in der Bekanntmachung bezüglich der Skizzeneinreichung zu finden?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': '8754681e'},
#  {'Question': 'Wo können Mietkosten in einer Zahlungsanweisung erfasst werden?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': 'fd15d8b2'},
#  {'Question': 'Unter welcher Position werden genehmigte Mietkosten abgerechnet?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': 'fd15d8b2'},
#  {'Question': 'In welchem Abschnitt sind genehmigte Mietkosten in einer Zahlungsanweisung anzuführen?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': 'fd15d8b2'},
#  {'Question': 'Welche Kennziffer wird für Mietausgaben in einer Abrechnung verwendet?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': 'fd15d8b2'},
#  {'Question': 'Wie sollen bewilligte Mietausgaben in der Abrechnung dargestellt werden?',
#   'Category': '--Antragstellung auf Kostenbasis (AZK)',
#   'Document': 'fd15d8b2'},
#  {'Question': 'Welche Vorschriften müssen bei der Auftragsvergabe beachtet werden?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '398616be'},
#  {'Question': 'Kann der Projektträger bei der Vergabe von Aufträgen beraten?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '398616be'},
#  {'Question': 'Welche Regelungen gelten bei der Unterschwellenvergabe?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '398616be'},
#  {'Question': 'Welche Gesetze sind relevant für die Vergabe eines Projekts?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '398616be'},
#  {'Question': 'Muss die Notwendigkeit eines Vergabeverfahrens geprüft werden?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '398616be'},
#  {'Question': 'Kann eine Person mehrere Förderanträge gleichzeitig einreichen?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '7c55e07d'},
#  {'Question': 'Welche Voraussetzungen müssen erfüllt sein, um mehrere Anträge parallel durchzuführen?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '7c55e07d'},
#  {'Question': 'Müssen materielle und finanzielle Ressourcen für jede Antragstellung gesichert sein?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '7c55e07d'},
#  {'Question': 'Muss bei jeder Antragstellung bestätigt werden, dass keine andere Förderung vorliegt?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '7c55e07d'},
#  {'Question': 'Kann eine Rechtsperson Anträge zu verschiedenen Förderbekanntmachungen einreichen?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '7c55e07d'},
#  {'Question': 'Kann ich meine Vorhabenbeschreibung auf Englisch einreichen?',
#   'Category': '---Allgemeine Informationen',
#   'Document': 'b795ca11'},
#  {'Question': 'Gibt es Ausnahmen für englischsprachige Vorhabenbeschreibungen?',
#   'Category': '---Allgemeine Informationen',
#   'Document': 'b795ca11'},
#  {'Question': 'Wo finde ich die Anforderungen für europäische Projekte?',
#   'Category': '---Allgemeine Informationen',
#   'Document': 'b795ca11'},
#  {'Question': 'In welcher Sprache muss die Vorhabenbeschreibung verfasst werden?',
#   'Category': '---Allgemeine Informationen',
#   'Document': 'b795ca11'},
#  {'Question': 'Sind Vorhabenbeschreibungen für europäische Maßnahmen anders geregelt?',
#   'Category': '---Allgemeine Informationen',
#   'Document': 'b795ca11'},
#  {'Question': 'Wo finde ich die Angaben zur Höhe der KMU-Förderung?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '884bcfaa'},
#  {'Question': 'Wie kann ich herausfinden, ob ein KMU Bonus verfügbar ist?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '884bcfaa'},
#  {'Question': 'Welche Information enthält die Förderbekanntmachung bezüglich der Förderhöhe für KMU?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '884bcfaa'},
#  {'Question': 'Gibt es eine Möglichkeit, die Förderhöhe für KMU festzustellen?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '884bcfaa'},
#  {'Question': 'Was muss ich prüfen, um Details zur KMU-Förderhöhe zu erfahren?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '884bcfaa'},
#  {'Question': 'In welcher Position des Antrages dürfen die Ausgaben für Publikationen angesetzt werden?',
#   'Category': '---Allgemeine Informationen',
#   'Document': 'a5d16457'},
#  {'Question': 'Was muss im Antrag ergänzt werden, um Ausgaben für Publikationen zu planen?',
#   'Category': '---Allgemeine Informationen',
#   'Document': 'a5d16457'},
#  {'Question': 'Unter welcher Position erfolgt die Abrechnung der Ausgaben für Publikationen?',
#   'Category': '---Allgemeine Informationen',
#   'Document': 'a5d16457'},
#  {'Question': 'Welche Position umfasst sonstige allgemeine Verwaltungsausgaben?',
#   'Category': '---Allgemeine Informationen',
#   'Document': 'a5d16457'},
#  {'Question': 'Welche Position muss auf dem Antrag geändert werden, um Publikationen aufzuführen?',
#   'Category': '---Allgemeine Informationen',
#   'Document': 'a5d16457'},
#  {'Question': 'Kann ich die pdf-Endfassung einer Zuwendungsantrag nachträglich ändern?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '1e6aeb32'},
#  {'Question': 'Was muss ich tun, wenn ich Änderungen in einer eingereichten Zahlungsanforderung vornehmen möchte?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '1e6aeb32'},
#  {'Question': 'Kann ich die beantragte Zuwendung in der pdf-Endfassung nachträglich erhöhen?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '1e6aeb32'},
#  {'Question': 'Wie kann ich kleine Änderungen in der Endfassung meines Antrags vermerken?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '1e6aeb32'},
#  {'Question': 'Was ist zu tun, wenn Anpassungen in einem Zwischennachweis erforderlich sind?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '1e6aeb32'},
#  {'Question': 'Ist eine Teilvorhabensbeschreibung bei Einzelvorhaben notwendig?',
#   'Category': '---Allgemeine Informationen',
#   'Document': 'f7516681'},
#  {'Question': 'Kann bei einem kleinen Verbund eine Teilvorhabensbeschreibung entfallen?',
#   'Category': '---Allgemeine Informationen',
#   'Document': 'f7516681'},
#  {'Question': 'Wann kann auf eine gesonderte TVB verzichtet werden?',
#   'Category': '---Allgemeine Informationen',
#   'Document': 'f7516681'},
#  {'Question': 'Muss eine TVB bei sehr ausführlicher Gesamtbeschreibung beigefügt werden?',
#   'Category': '---Allgemeine Informationen',
#   'Document': 'f7516681'},
#  {'Question': 'Sind Ausnahmen von der Pflicht zur Einsendung einer TVB möglich?',
#   'Category': '---Allgemeine Informationen',
#   'Document': 'f7516681'},
#  {'Question': 'Ist die Projektskizze ein formaler Förderantrag?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '296c9583'},
#  {'Question': 'Braucht die Projektskizze eine rechtsverbindliche Unterschrift?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '296c9583'},
#  {'Question': 'Wie ist die Projektskizze einzureichen?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '296c9583'},
#  {'Question': 'Bekomme ich eine Eingangsbestätigung nach der Einreichung der Skizze?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '296c9583'},
#  {'Question': 'Wann muss die Projektskizze postalisch versendet und unterschrieben werden?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '296c9583'},
#  {'Question': 'Müssen Antragsteller:innen immer in Deutschland ansässig sein?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '75a7e6a8'},
#  {'Question': 'Müssen Unternehmen im ausländischen Mehrheitsbesitz auch in Deutschland sein?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '75a7e6a8'},
#  {'Question': 'Welche Bedingungen gibt es für die Antragsberechtigung?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '75a7e6a8'},
#  {'Question': 'Können Antragsteller:innen aus dem Ausland ebenfalls antragsberechtigt sein?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '75a7e6a8'},
#  {'Question': 'Welche Maßnahmen müssen zur Risikominimierung vorgesehen werden?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '75a7e6a8'},
#  {'Question': 'Sind Kosten der Antragstellung förderfähig?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '6b5757e5'},
#  {'Question': 'Können Ausgaben vor dem Laufzeitbeginn gefördert werden?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '6b5757e5'},
#  {'Question': 'Werden Kosten durch den Antrag selbst finanziert?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '6b5757e5'},
#  {'Question': 'Welche Ausgaben sind vor dem Vorhabenbeginn förderfähig?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '6b5757e5'},
#  {'Question': 'Sind Kosten für Anträge förderbar?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '6b5757e5'},
#  {'Question': 'Sind die Kosten für die Einrichtung einer qualifizierten Signatur förderfähig?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '509a76c8'},
#  {'Question': 'Werden die Kosten für die Nutzung von qualifizierter Signatur übernommen?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '509a76c8'},
#  {'Question': 'Sind Ausgaben für die qualifizierte Signatur förderfähig?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '509a76c8'},
#  {'Question': 'Können die Kosten für Einrichtung und Nutzung von qualifizierter Signatur gefördert werden?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '509a76c8'},
#  {'Question': 'Gehören die Kosten für die qualifizierte Signatur zu förderfähigen Ausgaben?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '509a76c8'},
#  {'Question': 'Muss man Teilzeitkräfte in Vollzeitäquivalente umrechnen?',
#   'Category': '---Allgemeine Informationen',
#   'Document': 'e61e4ace'},
#  {'Question': 'Wie zählt man zwei Halbtagskräfte für den KMU-Status?',
#   'Category': '---Allgemeine Informationen',
#   'Document': 'e61e4ace'},
#  {'Question': 'Was bedeutet es, Beschäftigte in Vollzeitäquivalente anzugeben?',
#   'Category': '---Allgemeine Informationen',
#   'Document': 'e61e4ace'},
#  {'Question': 'Wie wird der Beschäftigungsstatus bei der KMU-Prüfung betrachtet?',
#   'Category': '---Allgemeine Informationen',
#   'Document': 'e61e4ace'},
#  {'Question': 'Sollen Teilzeitmitarbeiter zusammengezählt werden?',
#   'Category': '---Allgemeine Informationen',
#   'Document': 'e61e4ace'},
#  {'Question': 'Dürfen gemeinnützige Vereine Fördergelder beantragen?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '0aedfb89'},
#  {'Question': 'Sind alle gemeinnützigen Organisationen berechtigt, Fördergelder zu beantragen?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '0aedfb89'},
#  {'Question': 'Gilt die Fördermittelregelung für alle gemeinnützigen Vereine?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '0aedfb89'},
#  {'Question': 'Welche Organisationen dürfen Fördergelder anfordern?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '0aedfb89'},
#  {'Question': 'Können auch kleine gemeinnützige Vereine Fördergelder beantragen?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '0aedfb89'},
#  {'Question': 'Wann dürfen Bestellvorgänge und Arbeiten im Rahmen des Projektes beginnen?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '9f68548a'},
#  {'Question': 'Mit wem muss der mögliche Start des Fördervorhabens abgestimmt werden?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '9f68548a'},
#  {'Question': 'Was muss im Antragsformular bestätigt werden?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '9f68548a'},
#  {'Question': 'Wann gilt der Laufzeitbeginn für das Fördervorhaben?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '9f68548a'},
#  {'Question': 'Wer sind die Verbundpartner im Rahmen des Fördervorhabens?',
#   'Category': '---Allgemeine Informationen',
#   'Document': '9f68548a'},
#  ...]

# %%
relevance_total = []

for q in tqdm(ground_truth):
    doc_id = q['Document']
    results = elastic_search(query=q['Question'], category=q['Category'])
    relevance = [d['id'] == doc_id for d in results]
    relevance_total.append(relevance)
# Out:
#   0%|          | 0/4165 [00:00<?, ?it/s]/var/folders/81/16mr_0gj603btxm2xxhl704c0000gn/T/ipykernel_48040/2931147547.py:26: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   response = es_client.search(index=index_name, body=search_query)
# 100%|██████████| 4165/4165 [00:49<00:00, 84.44it/s]

# %% [markdown]
# - We iterate over all our queries in our ground truth, and check if our "ground truth" ID is among our results

# %%
example = [
    [True, False, False, False, False], # 1, 
    [False, False, False, False, False], # 0
    [False, False, False, False, False], # 0 
    [False, False, False, False, False], # 0
    [False, False, False, False, False], # 0 
    [True, False, False, False, False], # 1
    [True, False, False, False, False], # 1
    [True, False, False, False, False], # 1
    [True, False, False, False, False], # 1
    [True, False, False, False, False], # 1 
    [False, False, True, False, False],  # 1/3
    [False, False, False, False, False], # 0
]

# 1 => 1
# 2 => 1 / 2 = 0.5
# 3 => 1 / 3 = 0.3333
# 4 => 0.25
# 5 => 0.2
# rank => 1 / rank
# none => 0

# %%
def hit_rate(relevance_total):
    cnt = 0

    for line in relevance_total:
        if True in line:
            cnt = cnt + 1

    return cnt / len(relevance_total)

# %%
def mrr(relevance_total):
    total_score = 0.0

    for line in relevance_total:
        for rank in range(len(line)):
            if line[rank] == True:
                total_score = total_score + 1 / (rank + 1)

    return total_score / len(relevance_total)

# %%
hit_rate(example)
# Out:
# 0.5833333333333334

# %%
mrr(example)
# Out:
# 0.5277777777777778

# %% [markdown]
# - hit-rate (recall)
# - Mean Reciprocal Rank (mrr)

# %%
hit_rate(relevance_total), mrr(relevance_total)
# Out:
# (0.8424969987995198, 0.7043417366946788)

# %%
import minsearch

# Define the index, specifying the text and keyword fields based on your documents
index = minsearch.Index(
    text_fields=["Question", "Answer"],   # Text fields to search (Question and Answer)
    keyword_fields=["Category", "id"]     # Keyword fields (Category and id)
)

# Fit the index with your documents DataFrame
index.fit(documents)

# %%
def minsearch_search(query, category=None):
    # Define the boost for specific fields (giving more weight to 'Question')
    boost = {'Question': 3.0, 'Answer': 1.0}

    # Define the filter, if a category is provided
    filter_dict = {'Category': category} if category else {}

    # Perform the search with the query, filter, and boost
    results = index.search(
        query=query,
        filter_dict=filter_dict,  # Filter by 'Category' if provided
        boost_dict=boost,         # Boost 'Question' more than 'Answer'
        num_results=5             # Limit results to 5
    )

    return results

# %%
relevance_total = []

for q in tqdm(ground_truth):
    doc_id = q['Document']  # Assuming 'document' refers to the document's ID in the ground truth
    category = q['Category']  # Assuming the ground truth has a 'Category' field

    # Perform the search with the question and category
    results = minsearch_search(query=q['Question'], category=category)

    # Check if the correct document is in the search results
    relevance = [d['id'] == doc_id for d in results]
    relevance_total.append(relevance)
# Out:
# 100%|██████████| 4165/4165 [00:11<00:00, 374.20it/s]

# %%
hit_rate(relevance_total), mrr(relevance_total)
# Out:
# (0.7596638655462185, 0.6267026810724294)

# %% [markdown]
# Compare with ES results:
# ```
# (0.8424969987995198, 0.7043417366946788)
# ```

# %%
def evaluate(ground_truth, search_function):
    relevance_total = []

    for q in tqdm(ground_truth):
        doc_id = q['Document']
        results = search_function(q)
        relevance = [d['id'] == doc_id for d in results]
        relevance_total.append(relevance)

    return {
        'hit_rate': hit_rate(relevance_total),
        'mrr': mrr(relevance_total),
    }

# %%
evaluate(ground_truth, lambda q: elastic_search(q['Question'], q['Category']))
# Out:
#   0%|          | 0/4165 [00:00<?, ?it/s]/var/folders/81/16mr_0gj603btxm2xxhl704c0000gn/T/ipykernel_48040/2931147547.py:26: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   response = es_client.search(index=index_name, body=search_query)
# 100%|██████████| 4165/4165 [01:24<00:00, 49.28it/s]
# {'hit_rate': 0.8424969987995198, 'mrr': 0.7043417366946788}

# %%
evaluate(ground_truth, lambda q: minsearch_search(q['Question'], q['Category']))
# Out:
# 100%|██████████| 4165/4165 [00:10<00:00, 407.48it/s]
# {'hit_rate': 0.7596638655462185, 'mrr': 0.6267026810724294}
