# %%
import json

with open('documents-with-ids.json', 'rt') as f_in:
    documents = json.load(f_in)

# %%
from elasticsearch import Elasticsearch

# Create Elasticsearch client
es_client = Elasticsearch('http://localhost:9200')

# Define index settings with mappings matching your column names
index_settings = {
    "settings": {
        "number_of_shards": 1,
        "number_of_replicas": 0
    },
    "mappings": {
        "properties": {
            "Category": {"type": "keyword"},  # Category as a keyword
            "Question": {"type": "text"},     # Question as text (full-text search)
            "Answer": {"type": "text"},       # Answer as text (full-text search)
            "id": {"type": "keyword"},        # id as a keyword (for unique identification)
        }
    }
}

index_name = "eval_text"

# Delete index if it exists
es_client.indices.delete(index=index_name, ignore_unavailable=True)

# Create the new index
es_client.indices.create(index=index_name, body=index_settings)
# Out:
# /var/folders/81/16mr_0gj603btxm2xxhl704c0000gn/T/ipykernel_4391/3975706359.py:28: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   es_client.indices.create(index=index_name, body=index_settings)
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'eval_text'})

# %%
from tqdm.auto import tqdm

for doc in tqdm(documents):
    es_client.index(index=index_name, document=doc)
# Out:
# 100%|██████████| 429/429 [00:01<00:00, 260.96it/s]

# %%
def elastic_search(query, category=None):
    search_query = {
        "size": 5,  # Limit the search to 5 results
        "query": {
            "bool": {
                "must": {
                    "multi_match": {
                        "query": query,
                        "fields": ["Question^3", "Answer", "Category"],  # Search in 'Question' and 'Answer' fields, include category
                        "type": "most_fields"  # Use 'best_fields' for matching
                    }
                }
            }
        }
    }

    # Add a filter if a category is specified
    if category:
        search_query['query']['bool']['filter'] = {
            "term": {
                "Category": category  # Filter based on 'Category'
            }
        }

    # Execute the search query on the 'faq-documents' index
    response = es_client.search(index=index_name, body=search_query)
    
    # Collect the search results
    result_docs = []
    for hit in response['hits']['hits']:
        result_docs.append(hit['_source'])
    
    return result_docs

# %%
# elastic_search(
#     query="I just discovered the course. Can I still join?",
#     category="data-engineering-zoomcamp"
# )

# %%
import pandas as pd

# %%
df_ground_truth = pd.read_csv('ground-truth-data.csv')

# %%
ground_truth = df_ground_truth.to_dict(orient='records')

# %%
ground_truth
# Out:
# [{'Question': 'Sind Ausgaben für kostenpflichtige Literaturdatenbanken förderfähig?',
#   'Category': 'General/other',
#   'Document': '604174c6'},
#  {'Question': 'Gibt es finanzielle Unterstützung für den Zugriff auf Literaturdatenbanken?',
#   'Category': 'General/other',
#   'Document': '604174c6'},
#  {'Question': 'Kann ich die Kosten für Datenbanken in mein Projektbudget aufnehmen?',
#   'Category': 'General/other',
#   'Document': '604174c6'},
#  {'Question': 'Was passiert, wenn ich Literaturdatenbanken für mein Projekt nutzen muss?',
#   'Category': 'General/other',
#   'Document': '604174c6'},
#  {'Question': 'Sind nicht kostenlose Datenbanken auch förderfähig bei Projekten?',
#   'Category': 'General/other',
#   'Document': '604174c6'},
#  {'Question': 'Was ist der Mindestbetrag für die Abschreibung von Geräten?',
#   'Category': 'General/other',
#   'Document': '904dc228'},
#  {'Question': 'Bis zu welcher Summe können Geräte als Verbrauchsmaterial erworben werden?',
#   'Category': 'General/other',
#   'Document': '904dc228'},
#  {'Question': 'Wo finde ich die AfA-Tabellen zur Geräteabschreibung?',
#   'Category': 'General/other',
#   'Document': '904dc228'},
#  {'Question': 'Welche Kriterien gelten für die Klassifizierung von Geräten als Verbrauchsmaterial?',
#   'Category': 'General/other',
#   'Document': '904dc228'},
#  {'Question': 'Ab wann ist eine Abschreibung für technische Geräte notwendig?',
#   'Category': 'General/other',
#   'Document': '904dc228'},
#  {'Question': 'Welche Bestimmungen sind bei der Auftragserteilung zu beachten?',
#   'Category': 'General/other',
#   'Document': '5e60e572'},
#  {'Question': 'Wie hoch muss der Auftragswert sein, um mehrere Angebote einzuholen?',
#   'Category': 'General/other',
#   'Document': '5e60e572'},
#  {'Question': 'Wo finde ich Informationen zu Vergabeverfahren?',
#   'Category': 'General/other',
#   'Document': '5e60e572'},
#  {'Question': 'Kann ich Unterstützung bei der Auswahl von Angeboten erhalten?',
#   'Category': 'General/other',
#   'Document': '5e60e572'},
#  {'Question': 'Welche Gesetze beeinflussen die Vergabe von Aufträgen?',
#   'Category': 'General/other',
#   'Document': '5e60e572'},
#  {'Question': 'Wie viele Angestellte müssen in einer Firma beschäftigt sein, um als Großunternehmen klassifiziert zu werden?',
#   'Category': 'General/other',
#   'Document': 'c9a66a1d'},
#  {'Question': 'Welche Kriterien spielen bei der Einstufung von Unternehmen eine Rolle?',
#   'Category': 'General/other',
#   'Document': 'c9a66a1d'},
#  {'Question': 'Ab wann wird ein Unternehmen nicht mehr als mittelgroß betrachtet?',
#   'Category': 'General/other',
#   'Document': 'c9a66a1d'},
#  {'Question': 'Wie beeinflussen Bilanzsumme und Umsatz die Unternehmensklassifikation?',
#   'Category': 'General/other',
#   'Document': 'c9a66a1d'},
#  {'Question': 'Was sind die Voraussetzungen für eine Einstufung als KMU?',
#   'Category': 'General/other',
#   'Document': 'c9a66a1d'},
#  {'Question': 'Wo finde ich die Kontaktinformationen für die Antragsberatung?',
#   'Category': 'General/other',
#   'Document': 'dd1dcd6d'},
#  {'Question': 'Wer sind die Ansprechpartner für die Beantragung von Fördermitteln?',
#   'Category': 'General/other',
#   'Document': 'dd1dcd6d'},
#  {'Question': 'Wie kann ich eine Beratung für meinen Antrag erhalten?',
#   'Category': 'General/other',
#   'Document': 'dd1dcd6d'},
#  {'Question': 'Gibt es spezielle Personen, die ich für Anträge kontaktieren kann?',
#   'Category': 'General/other',
#   'Document': 'dd1dcd6d'},
#  {'Question': 'Wo kann ich Details zur Antragsberatung herausfinden?',
#   'Category': 'General/other',
#   'Document': 'dd1dcd6d'},
#  {'Question': 'Wer erhält den Zwischenbericht für das letzte Projektjahr?',
#   'Category': 'General/other',
#   'Document': '219ee5e8'},
#  {'Question': 'An wen wird der Bericht über das vergangene Jahr geschickt?',
#   'Category': 'General/other',
#   'Document': '219ee5e8'},
#  {'Question': 'Wo landet der Zwischenbericht nach seiner Fertigstellung?',
#   'Category': 'General/other',
#   'Document': '219ee5e8'},
#  {'Question': 'Wer ist der Empfänger des Berichts für das vorherige Projektjahr?',
#   'Category': 'General/other',
#   'Document': '219ee5e8'},
#  {'Question': 'An wen geht der Zwischenbericht nach dem Projekt?',
#   'Category': 'General/other',
#   'Document': '219ee5e8'},
#  {'Question': 'Wann ist der letzte mögliche Zeitpunkt für die Abrechnung der Jahressonderzahlung?',
#   'Category': 'General/other',
#   'Document': 'a3650aeb'},
#  {'Question': 'Welche Bedingungen müssen erfüllt sein, damit die Jahressonderzahlung anerkannt wird?',
#   'Category': 'General/other',
#   'Document': 'a3650aeb'},
#  {'Question': 'Wie wird der Verursachungsanteil für die Jahressonderzahlung ermittelt?',
#   'Category': 'General/other',
#   'Document': 'a3650aeb'},
#  {'Question': 'Welchen Einfluss hat der Verwendungsnachweis auf die Abrechnung der Jahressonderzahlung?',
#   'Category': 'General/other',
#   'Document': 'a3650aeb'},
#  {'Question': 'Was bedeutet die Zwölftel-Regelung im Zusammenhang mit der Jahressonderzahlung?',
#   'Category': 'General/other',
#   'Document': 'a3650aeb'},
#  {'Question': 'Wann ist die Antragstellung für die Mittelverschiebung erforderlich?',
#   'Category': 'General/other',
#   'Document': 'e2fd3e19'},
#  {'Question': 'Bis wann darf ich eine Verschiebung der Mittel beantragen?',
#   'Category': 'General/other',
#   'Document': 'e2fd3e19'},
#  {'Question': 'Was muss ich beachten, um die Mittelverschiebung rechtzeitig zu beantragen?',
#   'Category': 'General/other',
#   'Document': 'e2fd3e19'},
#  {'Question': 'Welches Datum ist entscheidend für die letzte Zahlungsanforderung?',
#   'Category': 'General/other',
#   'Document': 'e2fd3e19'},
#  {'Question': 'An welchem Stichtag muss die Antragstellung für die Mittelverschiebung erfolgen?',
#   'Category': 'General/other',
#   'Document': 'e2fd3e19'},
#  {'Question': 'Wann ist die Frist für den Zwischennachweis?',
#   'Category': 'General/other',
#   'Document': 'f73bd010'},
#  {'Question': 'Bis zu welchem Datum muss der Zwischenbericht eingereicht werden?',
#   'Category': 'General/other',
#   'Document': 'f73bd010'},
#  {'Question': 'Wann erfolgt die Erinnerung an den Abgabetermin für den Zwischennachweis?',
#   'Category': 'General/other',
#   'Document': 'f73bd010'},
#  {'Question': 'Was ist der letzte mögliche Abgabetermin für den Zwischenbericht?',
#   'Category': 'General/other',
#   'Document': 'f73bd010'},
#  {'Question': 'In welcher Form wird der Termin für den Zwischennachweis kommuniziert?',
#   'Category': 'General/other',
#   'Document': 'f73bd010'},
#  {'Question': 'Was ist der maximale Abrechnungsbetrag für die Position 0831?',
#   'Category': 'General/other',
#   'Document': '47e1f1d0'},
#  {'Question': 'Wie hoch dürfen die Ausgaben für Gegenstände in der Position 0831 sein?',
#   'Category': 'General/other',
#   'Document': '47e1f1d0'},
#  {'Question': 'Kann ich einen Artikel bis zu 800 Euro in der Position 0831 abrechnen?',
#   'Category': 'General/other',
#   'Document': '47e1f1d0'},
#  {'Question': 'Gibt es eine Obergrenze für Abrechnungen in der Kategorie 0831?',
#   'Category': 'General/other',
#   'Document': '47e1f1d0'},
#  {'Question': 'Welche Beträge kann ich für die Position 0831 angeben?',
#   'Category': 'General/other',
#   'Document': '47e1f1d0'},
#  {'Question': 'Können nur Forschungseinrichtungen im Konsortium sein?',
#   'Category': 'General/other',
#   'Document': '8e71c8b3'},
#  {'Question': 'Welche Arten von Einrichtungen sind für das Konsortium zugelassen?',
#   'Category': 'General/other',
#   'Document': '8e71c8b3'},
#  {'Question': 'Wo finde ich Informationen zu den förderfähigen Antragsstellern?',
#   'Category': 'General/other',
#   'Document': '8e71c8b3'},
#  {'Question': 'Gibt es Vorgaben zu den Mitgliedern im Konsortium?',
#   'Category': 'General/other',
#   'Document': '8e71c8b3'},
#  {'Question': 'Ist es möglich, andere Organisationen im Konsortium zu haben?',
#   'Category': 'General/other',
#   'Document': '8e71c8b3'},
#  {'Question': 'Ist es möglich, ein Projekttreffen außerhalb Deutschlands abzuhalten?',
#   'Category': 'General/other',
#   'Document': '41321414'},
#  {'Question': 'Unter welchen Bedingungen sind Meetings im Ausland förderfähig?',
#   'Category': 'General/other',
#   'Document': '41321414'},
#  {'Question': 'Könnten Kosten für Dienstreisen ins Ausland finanziert werden?',
#   'Category': 'General/other',
#   'Document': '41321414'},
#  {'Question': 'Wie muss ich die Notwendigkeit von Auslandsmeetings begründen?',
#   'Category': 'General/other',
#   'Document': '41321414'},
#  {'Question': 'Gilt das auch für externe Teilnehmer bei Treffen im Ausland?',
#   'Category': 'General/other',
#   'Document': '41321414'},
#  {'Question': 'Ist es möglich, dass eine Person mehrere Anträge gleichzeitig einreicht?',
#   'Category': 'General/other',
#   'Document': '9ddb0aee'},
#  {'Question': 'Welche Voraussetzungen müssen erfüllt sein, um mehrere Anträge zu stellen?',
#   'Category': 'General/other',
#   'Document': '9ddb0aee'},
#  {'Question': 'Muss ich bestätigen, dass das Vorhaben nicht doppelt gefördert wird?',
#   'Category': 'General/other',
#   'Document': '9ddb0aee'},
#  {'Question': 'Darf ich Anträge zu verschiedenen Programmen gleichzeitig einreichen?',
#   'Category': 'General/other',
#   'Document': '9ddb0aee'},
#  {'Question': 'Was passiert, wenn ich nicht über ausreichend Kapazitäten verfüge, um mehrere Projekte durchzuführen?',
#   'Category': 'General/other',
#   'Document': '9ddb0aee'},
#  {'Question': 'Ist es erlaubt, eine Fördermittelanfrage für mehrere Monate zu stellen?',
#   'Category': 'General/other',
#   'Document': '27b6d199'},
#  {'Question': 'Wie lange im Voraus kann ich Ausgaben für Förderprojekte anfordern?',
#   'Category': 'General/other',
#   'Document': '27b6d199'},
#  {'Question': 'Kann ich auch zukünftige Ausgaben in meiner Zahlungsanforderung berücksichtigen?',
#   'Category': 'General/other',
#   'Document': '27b6d199'},
#  {'Question': 'Gibt es Einschränkungen bezüglich der Anpassung von Mittelanforderungen über mehrere Monate?',
#   'Category': 'General/other',
#   'Document': '27b6d199'},
#  {'Question': 'Was passiert, wenn meine geschätzten Ausgaben über die 6 Wochen hinausgehen?',
#   'Category': 'General/other',
#   'Document': '27b6d199'},
#  {'Question': 'Ist es möglich, das Formular im Internet zu unterschreiben?',
#   'Category': 'General/other',
#   'Document': 'c411e408'},
#  {'Question': 'Welche Art von Signatur wird für das Easy-Online Formular benötigt?',
#   'Category': 'General/other',
#   'Document': 'c411e408'},
#  {'Question': 'Was benötige ich, um online zu unterschreiben?',
#   'Category': 'General/other',
#   'Document': 'c411e408'},
#  {'Question': 'Wo kann ich die Software für das Kartenlesegerät finden?',
#   'Category': 'General/other',
#   'Document': 'c411e408'},
#  {'Question': 'Was ist eine qualifizierte elektronische Signatur und wie erhalte ich sie?',
#   'Category': 'General/other',
#   'Document': 'c411e408'},
#  {'Question': 'Können Personalkosten, die aus öffentlichen Mitteln stammen, im Projekt beantragt werden?',
#   'Category': 'General/other',
#   'Document': '591a5d5e'},
#  {'Question': 'Ist es erlaubt, Mitarbeiter, die öffentlich finanziert werden, in diesem Projekt zu berücksichtigen?',
#   'Category': 'General/other',
#   'Document': '591a5d5e'},
#  {'Question': 'Darf ich Personalausgaben, die von öffentlichen Haushalten gedeckt sind, durch dieses Projekt finanzieren?',
#   'Category': 'General/other',
#   'Document': '591a5d5e'},
#  {'Question': 'Welche Regelungen gibt es für die Abrechnung von Personal, das aus öffentlichen Geldern finanziert wird?',
#   'Category': 'General/other',
#   'Document': '591a5d5e'},
#  {'Question': 'Sind Gehälter von durch öffentliche Haushalte finanzierten Angestellten in diesem Projekt zulässig?',
#   'Category': 'General/other',
#   'Document': '591a5d5e'},
#  {'Question': 'Welche Kosten können für Abschreibungen beantragt werden?',
#   'Category': 'General/other',
#   'Document': '27a7fbe8'},
#  {'Question': 'Gilt das für alle Arten von Anlagen oder nur für spezifische?',
#   'Category': 'General/other',
#   'Document': '27a7fbe8'},
#  {'Question': 'Wie lange dürfen die Investitionen im Projekt angesetzt werden?',
#   'Category': 'General/other',
#   'Document': '27a7fbe8'},
#  {'Question': 'Müssen die Anlagen neu angeschafft werden, um Abschreibungen geltend zu machen?',
#   'Category': 'General/other',
#   'Document': '27a7fbe8'},
#  {'Question': 'Wie erfolgt die Berechnung der linearen Abschreibung?',
#   'Category': 'General/other',
#   'Document': '27a7fbe8'},
#  {'Question': 'Können Bildungseinrichtungen ihre Kosten nach dem Landesreisekostengesetz geltend machen?',
#   'Category': 'General/other',
#   'Document': '28b434a2'},
#  {'Question': 'Sind Hochschulen berechtigt, Ausgaben auf Basis des Landesreisekostengesetzes abzurechnen?',
#   'Category': 'General/other',
#   'Document': '28b434a2'},
#  {'Question': 'Gilt das Landesreisekostengesetz auch für wissenschaftliche Institutionen bei der Kostenabrechnung?',
#   'Category': 'General/other',
#   'Document': '28b434a2'},
#  {'Question': 'Dürfen research facilities Ausgaben gemäß dem Landesreisekostengesetz verrechnen?',
#   'Category': 'General/other',
#   'Document': '28b434a2'},
#  {'Question': 'Ist die Abrechnung nach dem Landesreisekostengesetz für akademische Einrichtungen erlaubt?',
#   'Category': 'General/other',
#   'Document': '28b434a2'},
#  {'Question': 'Ist es möglich, Abschreibungen für spezielle Geräte zu beantragen?',
#   'Category': 'General/other',
#   'Document': 'a75612f0'},
#  {'Question': 'Wie werden die Abschreibungen für bestimmte Anlagen im Projekt berücksichtigt?',
#   'Category': 'General/other',
#   'Document': 'a75612f0'},
#  {'Question': 'Darf ich auch die vorhandenen Geräte für die Abrechnung einbeziehen?',
#   'Category': 'General/other',
#   'Document': 'a75612f0'},
#  {'Question': 'Welche Nutzungsdauer muss für die Abrechnung von Geräten angenommen werden?',
#   'Category': 'General/other',
#   'Document': 'a75612f0'},
#  {'Question': 'Gibt es Einschränkungen für die pauschalierte Abrechnung von Anlagen?',
#   'Category': 'General/other',
#   'Document': 'a75612f0'},
#  {'Question': 'Sind die Ausgaben für Stellenausschreibungen erstattungsfähig?',
#   'Category': 'General/other',
#   'Document': '95b17a1c'},
#  {'Question': 'Welche Alternativen gibt es für Hochschulen bezüglich Stellenausschreibungskosten?',
#   'Category': 'General/other',
#   'Document': '95b17a1c'},
#  {'Question': 'Wie werden Stellenausschreibungskosten in Unternehmen behandelt?',
#   'Category': 'General/other',
#   'Document': '95b17a1c'},
#  {'Question': 'Können Hochschulen spezielle Mittel für Stellenausschreibungen beantragen?',
#   'Category': 'General/other',
#   'Document': '95b17a1c'},
#  {'Question': 'Gibt es spezielle Regelungen für Unternehmen zu diesen Kosten?',
#   'Category': 'General/other',
#   'Document': '95b17a1c'},
#  {'Question': 'Ist es möglich, die Vorhabenbeschreibung auf Englisch zu schreiben?',
#   'Category': 'General/other',
#   'Document': 'c420d112'},
#  {'Question': 'Gibt es besondere Regeln für internationale Projekte bei der Beschreibung?',
#   'Category': 'General/other',
#   'Document': 'c420d112'},
#  {'Question': 'Müssen alle Beschreibungen immer in Deutsch erstellt werden?',
#   'Category': 'General/other',
#   'Document': 'c420d112'},
#  {'Question': 'Wo finde ich die Förderrichtlinie für die speziellen Anforderungen?',
#   'Category': 'General/other',
#   'Document': 'c420d112'},
#  {'Question': 'Gilt die Pflicht zur deutschen Sprache für alle Anträge?',
#   'Category': 'General/other',
#   'Document': 'c420d112'},
#  {'Question': 'Welche Kosten können für Schulungen beantragt werden?',
#   'Category': 'General/other',
#   'Document': 'c76027e3'},
#  {'Question': 'Wie beantrage ich Ausgaben für ein Seminar?',
#   'Category': 'General/other',
#   'Document': 'c76027e3'},
#  {'Question': 'Sind alle Veranstaltungsgebühren förderfähig?',
#   'Category': 'General/other',
#   'Document': 'c76027e3'},
#  {'Question': 'Was muss ich beachten, um Schulungskosten abzurechnen?',
#   'Category': 'General/other',
#   'Document': 'c76027e3'},
#  {'Question': 'Wann erhalte ich eine Entscheidung über die Bewilligung meiner Anträge?',
#   'Category': 'General/other',
#   'Document': 'c76027e3'},
#  {'Question': 'Ist es möglich, Zinsen auf die Projektpauschale zu generieren?',
#   'Category': 'General/other',
#   'Document': '1951580d'},
#  {'Question': 'Wie wird die Projektpauschale von den Hochschulen eingesetzt?',
#   'Category': 'General/other',
#   'Document': '1951580d'},
#  {'Question': 'Könnte die Hochschule die Projektpauschale anders verwenden als vorgesehen?',
#   'Category': 'General/other',
#   'Document': '1951580d'},
#  {'Question': 'In welchem Umfang dürfen Hochschulen die Projektpauschale verwenden?',
#   'Category': 'General/other',
#   'Document': '1951580d'},
#  {'Question': 'Was sind die indirekten Ausgaben, die durch die Projektpauschale abgedeckt werden?',
#   'Category': 'General/other',
#   'Document': '1951580d'},
#  {'Question': 'Sind in profi-online Vorlagen für Beleglisten vorhanden?',
#   'Category': 'General/other',
#   'Document': 'c78ee9e8'},
#  {'Question': 'Wo finde ich Beleglisten für meine Unterlagen?',
#   'Category': 'General/other',
#   'Document': 'c78ee9e8'},
#  {'Question': 'Gibt es eine Möglichkeit, Beleglisten in der Plattform zu erstellen?',
#   'Category': 'General/other',
#   'Document': 'c78ee9e8'},
#  {'Question': 'Kann ich die Beleglisten aus dem Formularschrank des Bundes verwenden?',
#   'Category': 'General/other',
#   'Document': 'c78ee9e8'},
#  {'Question': 'Was muss ich tun, um Beleglisten in profi-online zu nutzen?',
#   'Category': 'General/other',
#   'Document': 'c78ee9e8'},
#  {'Question': 'Wo finde ich ein Formular für die Inventarliste?',
#   'Category': 'General/other',
#   'Document': '2bb12cf4'},
#  {'Question': 'Kann ich eine eigene Liste für die Inventarierung erstellen?',
#   'Category': 'General/other',
#   'Document': '2bb12cf4'},
#  {'Question': 'Wie sollte ich die Inventarnummern auf meiner Liste anordnen?',
#   'Category': 'General/other',
#   'Document': '2bb12cf4'},
#  {'Question': 'Gibt es Vorgaben zur Erstellung einer Inventarliste?',
#   'Category': 'General/other',
#   'Document': '2bb12cf4'},
#  {'Question': 'Darf ich die Belegliste nach meinen Bedürfnissen anpassen?',
#   'Category': 'General/other',
#   'Document': '2bb12cf4'},
#  {'Question': 'Wo kann ich das Formular für Zwischenberichte finden?',
#   'Category': 'General/other',
#   'Document': '4d48af45'},
#  {'Question': 'Benötige ich zusätzlich zum Zwischennachweis ein weiteres Formular?',
#   'Category': 'General/other',
#   'Document': '4d48af45'},
#  {'Question': 'Welche Formulare muss ich einreichen, um Fördermittel zu beantragen?',
#   'Category': 'General/other',
#   'Document': '4d48af45'},
#  {'Question': 'Gibt es Unterschiede zwischen den Formularen für Kosten- und Ausgabenbasis?',
#   'Category': 'General/other',
#   'Document': '4d48af45'},
#  {'Question': 'Kann ich die Formulare für Zwischenberichte online herunterladen?',
#   'Category': 'General/other',
#   'Document': '4d48af45'},
#  {'Question': 'Was ist die maximale finanzielle Grenze für Hotelübernachtungen?',
#   'Category': 'General/other',
#   'Document': '1bb0839e'},
#  {'Question': 'An welche Regelung sollte ich mich bezüglich der Hotelkosten halten?',
#   'Category': 'General/other',
#   'Document': '1bb0839e'},
#  {'Question': 'Wie hoch sind die Kosten, die für Hotelbuchungen erstattet werden können?',
#   'Category': 'General/other',
#   'Document': '1bb0839e'},
#  {'Question': 'Gibt es gesetzliche Vorgaben für die Finanzierung von Übernachtungen?',
#   'Category': 'General/other',
#   'Document': '1bb0839e'},
#  {'Question': 'Wo finde ich Informationen zur Kostenbegrenzung für Hotels bei Reisen?',
#   'Category': 'General/other',
#   'Document': '1bb0839e'},
#  {'Question': 'Wie oft kann ich Zahlungsanforderungen einreichen?',
#   'Category': 'General/other',
#   'Document': '947ec19a'},
#  {'Question': 'Gibt es eine Deadline für die letzte Zahlungsanforderung?',
#   'Category': 'General/other',
#   'Document': '947ec19a'},
#  {'Question': 'Wie lange im Voraus sollte ich meine Ausgaben schätzen?',
#   'Category': 'General/other',
#   'Document': '947ec19a'},
#  {'Question': 'Könnte ich jeden Monat eine Zahlungsanforderung stellen?',
#   'Category': 'General/other',
#   'Document': '947ec19a'},
#  {'Question': 'Was muss ich bei der Einreichung meiner letzten Zahlungsanforderung beachten?',
#   'Category': 'General/other',
#   'Document': '947ec19a'},
#  {'Question': 'Kann ich eine Geräteliste selbst erstellen?',
#   'Category': 'General/other',
#   'Document': 'd4b8f8fc'},
#  {'Question': 'Woher bekomme ich Informationen zur Geräteliste?',
#   'Category': 'General/other',
#   'Document': 'd4b8f8fc'},
#  {'Question': 'Wer erstellt die Geräteliste für mein Projekt?',
#   'Category': 'General/other',
#   'Document': 'd4b8f8fc'},
#  {'Question': 'Ist eine Vorlage für die Geräteaufstellung vorhanden?',
#   'Category': 'General/other',
#   'Document': 'd4b8f8fc'},
#  {'Question': 'Wie erhalte ich die Geräteliste für mein Vorhaben?',
#   'Category': 'General/other',
#   'Document': 'd4b8f8fc'},
#  {'Question': 'Kann ich eine Vorlage für einen Teilantrag erhalten?',
#   'Category': 'General/other',
#   'Document': '0fb759a1'},
#  {'Question': 'Wie erhalte ich Informationen zur Antragstellung?',
#   'Category': 'General/other',
#   'Document': '0fb759a1'},
#  {'Question': 'Wann bekomme ich eine E-Mail mit den Details zum Antrag?',
#   'Category': 'General/other',
#   'Document': '0fb759a1'},
#  {'Question': 'Wo finde ich den Link zur Antragstellung?',
#   'Category': 'General/other',
#   'Document': '0fb759a1'},
#  {'Question': 'Was passiert, wenn meine Skizze gewählt wird?',
#   'Category': 'General/other',
#   'Document': '0fb759a1'},
#  {'Question': 'Existiert ein maximaler Betrag für Aufträge?',
#   'Category': 'General/other',
#   'Document': 'b603be94'},
#  {'Question': 'Wie verhält sich Eigentätigkeit zu Fremdleistungen in Projekten?',
#   'Category': 'General/other',
#   'Document': 'b603be94'},
#  {'Question': 'Gibt es spezielle Anforderungen bei höheren Auftragssummen?',
#   'Category': 'General/other',
#   'Document': 'b603be94'},
#  {'Question': 'Wann ist ein Angebot auf Kosten- oder Ausgabenbasis erforderlich?',
#   'Category': 'General/other',
#   'Document': 'b603be94'},
#  {'Question': 'Welche Bedingungen gelten für FE-Aufträge in Bezug auf das Verhältnis von Leistungen?',
#   'Category': 'General/other',
#   'Document': 'b603be94'},
#  {'Question': 'Wo finde ich Informationen zu Sachberichten für Fördermittelanträge?',
#   'Category': 'General/other',
#   'Document': 'eabb4d82'},
#  {'Question': 'Bietet VDI-VDE-IT Vorlagen für Sachberichte an?',
#   'Category': 'General/other',
#   'Document': 'eabb4d82'},
#  {'Question': 'Welche Arten von Sachberichten sind für Fördermittel nötig?',
#   'Category': 'General/other',
#   'Document': 'eabb4d82'},
#  {'Question': 'Kann ich spezifische Berichte für AZK und AZA anfordern?',
#   'Category': 'General/other',
#   'Document': 'eabb4d82'},
#  {'Question': 'Wie sollte ich meine Sachberichte für den Verwendungsnachweis gestalten?',
#   'Category': 'General/other',
#   'Document': 'eabb4d82'},
#  {'Question': 'Wo finde ich den Antrag für die Zahlungsanforderung beim BMBF?',
#   'Category': 'General/other',
#   'Document': '9332533c'},
#  {'Question': 'Wie kann ich eine Zahlungsanforderung im Rahmen der Förderung einreichen?',
#   'Category': 'General/other',
#   'Document': '9332533c'},
#  {'Question': 'Gibt es eine spezielle Plattform zur Bearbeitung von Zahlungsanforderungen?',
#   'Category': 'General/other',
#   'Document': '9332533c'},
#  {'Question': 'Kann ich die Zahlungsanforderung auch ohne prof-Online einreichen?',
#   'Category': 'General/other',
#   'Document': '9332533c'},
#  {'Question': 'Welche Schritte sind notwendig, um eine Förderzahlung zu beantragen?',
#   'Category': 'General/other',
#   'Document': '9332533c'},
#  {'Question': 'Wie oft kann ich die finanziellen Mittel anfordern?',
#   'Category': 'General/other',
#   'Document': '95f070ea'},
#  {'Question': 'In welchen Abständen sind die Zahlungsanforderungen einzureichen?',
#   'Category': 'General/other',
#   'Document': '95f070ea'},
#  {'Question': 'Wann genau kann ich die Gelder für das erste Quartal anfordern?',
#   'Category': 'General/other',
#   'Document': '95f070ea'},
#  {'Question': 'Wie lange dauert es, bis ich nach der Antragstellung die Gelder erhalte?',
#   'Category': 'General/other',
#   'Document': '95f070ea'},
#  {'Question': 'Was muss ich über die Berichterstattung des letzten Haushaltsjahres wissen?',
#   'Category': 'General/other',
#   'Document': '95f070ea'},
#  {'Question': 'Wie hoch ist die Förderung für kleine und mittlere Unternehmen?',
#   'Category': 'General/other',
#   'Document': 'd9ab4109'},
#  {'Question': 'Wo finde ich Informationen zur finanziellen Unterstützung von KMU?',
#   'Category': 'General/other',
#   'Document': 'd9ab4109'},
#  {'Question': 'Gibt es einen speziellen Bonus für KMU und wie wird dieser berechnet?',
#   'Category': 'General/other',
#   'Document': 'd9ab4109'},
#  {'Question': 'Kann ich die Details zur Förderhöhe für KMU online nachlesen?',
#   'Category': 'General/other',
#   'Document': 'd9ab4109'},
#  {'Question': 'Welche Bedingungen müssen erfüllt sein, um die KMU-Förderung zu erhalten?',
#   'Category': 'General/other',
#   'Document': 'd9ab4109'},
#  {'Question': 'Wie sollte ich Geräte im AZA Antrag kategorisieren?',
#   'Category': 'General/other',
#   'Document': 'd7efbe51'},
#  {'Question': 'Wo trage ich Geräte mit einem Wert von über 800 Euro ein?',
#   'Category': 'General/other',
#   'Document': 'd7efbe51'},
#  {'Question': 'In welcher Position im Antrag sind Geräte unter 800 Euro zu nennen?',
#   'Category': 'General/other',
#   'Document': 'd7efbe51'},
#  {'Question': 'Wie gliedere ich die Geräte im AZA Antrag auf?',
#   'Category': 'General/other',
#   'Document': 'd7efbe51'},
#  {'Question': 'Kann ich Geräte bis 800 Euro in der selben Position angeben?',
#   'Category': 'General/other',
#   'Document': 'd7efbe51'},
#  {'Question': 'Welche Kriterien bestimmen die Abrechnungsposition für Software?',
#   'Category': 'General/other',
#   'Document': '68c8ef66'},
#  {'Question': 'Wie wird die Abrechnung von Software geregelt, wenn keine Lizenzen gekauft werden?',
#   'Category': 'General/other',
#   'Document': '68c8ef66'},
#  {'Question': 'Welche Betragsgrenze gilt für die Planung der Softwarekäufe?',
#   'Category': 'General/other',
#   'Document': '68c8ef66'},
#  {'Question': 'In welcher Kategorie wird Software eingeordnet, wenn die Kosten unter einem bestimmten Betrag liegen?',
#   'Category': 'General/other',
#   'Document': '68c8ef66'},
#  {'Question': 'Was muss ich beachten, wenn ich Software über 800 Euro erwerben möchte?',
#   'Category': 'General/other',
#   'Document': '68c8ef66'},
#  {'Question': 'Wo im Antrag sind die Veröffentlichungskosten einzutragen?',
#   'Category': 'General/other',
#   'Document': '522ba19d'},
#  {'Question': 'Wie sollten die Ausgaben für Publikationen im Antrag gekennzeichnet werden?',
#   'Category': 'General/other',
#   'Document': '522ba19d'},
#  {'Question': 'In welchem Abschnitt plane ich die Kosten für Publikationen?',
#   'Category': 'General/other',
#   'Document': '522ba19d'},
#  {'Question': 'Wo erfolgt die Abrechnung der Publikationsausgaben im Antrag?',
#   'Category': 'General/other',
#   'Document': '522ba19d'},
#  {'Question': 'Welche Bezeichnung muss für Publikationen im Antrag verwendet werden?',
#   'Category': 'General/other',
#   'Document': '522ba19d'},
#  {'Question': 'Welche Rolle spielen assoziierte Partner in Projekten?',
#   'Category': 'General/other',
#   'Document': '3bf179c3'},
#  {'Question': 'Wie können wir Assoziierte Partner in ein Konsortium integrieren?',
#   'Category': 'General/other',
#   'Document': '3bf179c3'},
#  {'Question': 'Inwiefern sind Partner gegenüber Fördermittelgebern verantwortlich?',
#   'Category': 'General/other',
#   'Document': '3bf179c3'},
#  {'Question': 'Was ist ein Konsortialvertrag und wie hilft er Partnerschaften?',
#   'Category': 'General/other',
#   'Document': '3bf179c3'},
#  {'Question': 'Welche Aufgaben übernehmen assoziierte Partner im Rahmen von Förderprojekten?',
#   'Category': 'General/other',
#   'Document': '3bf179c3'},
#  {'Question': 'Muss ich bei einer anteiligen Rückzahlung auch einen Teil der Projektpauschale zurückgeben?',
#   'Category': 'General/other',
#   'Document': '2ed06d9d'},
#  {'Question': 'Wie wirkt sich eine Reduzierung der Ausgaben auf die Projektpauschale aus?',
#   'Category': 'General/other',
#   'Document': '2ed06d9d'},
#  {'Question': 'Bezieht sich die Rückzahlung der Projektpauschale nur auf Hochschulen?',
#   'Category': 'General/other',
#   'Document': '2ed06d9d'},
#  {'Question': 'In welcher Höhe wird die Projektpauschale bei verringerter Förderung angepasst?',
#   'Category': 'General/other',
#   'Document': '2ed06d9d'},
#  {'Question': 'Gibt es besondere Regelungen zur Rückzahlung der Projektpauschale bei Hochschulförderungen?',
#   'Category': 'General/other',
#   'Document': '2ed06d9d'},
#  {'Question': 'Sind Mietwagenkosten förderfähig?',
#   'Category': 'General/other',
#   'Document': '7a57f4bd'},
#  {'Question': 'Wie wird die Notwendigkeit eines Mietwagens im Antrag beschrieben?',
#   'Category': 'General/other',
#   'Document': '7a57f4bd'},
#  {'Question': 'Darf ein Mietwagen nur für bestimmte Zwecke genutzt werden?',
#   'Category': 'General/other',
#   'Document': '7a57f4bd'},
#  {'Question': 'Welche Anforderungen gibt es für die Zuwendung von Mietwagenkosten?',
#   'Category': 'General/other',
#   'Document': '7a57f4bd'},
#  {'Question': 'Muss ich die Nutzung des Mietwagens im Antrag rechtfertigen?',
#   'Category': 'General/other',
#   'Document': '7a57f4bd'},
#  {'Question': 'Muss ich bei einem Personalwechsel den Projektträger benachrichtigen?',
#   'Category': 'General/other',
#   'Document': 'f893dc26'},
#  {'Question': 'Welche Voraussetzungen gelten für den Einsatz neuer Mitarbeitenden im Projekt?',
#   'Category': 'General/other',
#   'Document': 'f893dc26'},
#  {'Question': 'Gilt die Informationspflicht auch bei Projekten auf Ausgabenbasis?',
#   'Category': 'General/other',
#   'Document': 'f893dc26'},
#  {'Question': 'Wie erkenne ich, ob eine Mittelumwidmung notwendig ist?',
#   'Category': 'General/other',
#   'Document': 'f893dc26'},
#  {'Question': 'Können Mitarbeiter ohne Zustimmung des Zuwendungsgebers wechseln?',
#   'Category': 'General/other',
#   'Document': 'f893dc26'},
#  {'Question': 'Gibt es Ausnahmen zur Frist für den Nachweis?',
#   'Category': 'General/other',
#   'Document': 'a5339c29'},
#  {'Question': 'Wie lange habe ich Zeit, um den Zwischennachweis einzureichen?',
#   'Category': 'General/other',
#   'Document': 'a5339c29'},
#  {'Question': 'Was passiert, wenn ich die Frist für den Nachweis versäume?',
#   'Category': 'General/other',
#   'Document': 'a5339c29'},
#  {'Question': 'Kann ich eine Verlängerung der Frist beantragen?',
#   'Category': 'General/other',
#   'Document': 'a5339c29'},
#  {'Question': 'Wo finde ich weitere Informationen zu den Fristen im Zuwendungsbescheid?',
#   'Category': 'General/other',
#   'Document': 'a5339c29'},
#  {'Question': 'Wird die Projektpauschale dem zentralen Budget zugewiesen?',
#   'Category': 'General/other',
#   'Document': '23823953'},
#  {'Question': 'Welche Zwecke umfasst die Projektpauschale für Forschungsprojekte?',
#   'Category': 'General/other',
#   'Document': '23823953'},
#  {'Question': 'Wer entscheidet über die Verwendung der Projektpauschale?',
#   'Category': 'General/other',
#   'Document': '23823953'},
#  {'Question': 'Welche indirekten Kosten deckt die Projektpauschale ab?',
#   'Category': 'General/other',
#   'Document': '23823953'},
#  {'Question': 'Wie wird die Projektpauschale von Hochschulen verwendet?',
#   'Category': 'General/other',
#   'Document': '23823953'},
#  {'Question': 'Kann ich eine andere Position anfragen, auch wenn sie nicht genehmigt ist?',
#   'Category': 'General/other',
#   'Document': 'd1840c13'},
#  {'Question': 'Welche Schritte sind erforderlich für eine Umwidmung in eine nicht genehmigte Position?',
#   'Category': 'General/other',
#   'Document': 'd1840c13'},
#  {'Question': 'Muss der Umwidmungsantrag einen bestimmten Grund enthalten?',
#   'Category': 'General/other',
#   'Document': 'd1840c13'},
#  {'Question': 'Wer entscheidet über den Umwidmungsantrag und wie läuft der Prozess ab?',
#   'Category': 'General/other',
#   'Document': 'd1840c13'},
#  {'Question': 'Gibt es Fristen, die ich bei der Umwidmung beachten muss?',
#   'Category': 'General/other',
#   'Document': 'd1840c13'},
#  {'Question': 'Kann ich meinen Zwischennachweis im Folgejahr anpassen?',
#   'Category': 'General/other',
#   'Document': '26416acb'},
#  {'Question': 'Gibt es eine Frist für die Korrektur des Zwischennachweises?',
#   'Category': 'General/other',
#   'Document': '26416acb'},
#  {'Question': 'Wie gehe ich mit überzahlten Beträgen nach einer Korrektur um?',
#   'Category': 'General/other',
#   'Document': '26416acb'},
#  {'Question': 'Sollte ich Änderungen am Zwischennachweis erst beim Verwendungsnachweis vornehmen?',
#   'Category': 'General/other',
#   'Document': '26416acb'},
#  {'Question': 'Welche Faktoren beeinflussen die Entscheidung zur Korrektur des Nachweises?',
#   'Category': 'General/other',
#   'Document': '26416acb'},
#  {'Question': 'Welche Aspekte der Öffentlichkeitsarbeit können gefördert werden?',
#   'Category': 'General/other',
#   'Document': 'ae51e0f8'},
#  {'Question': 'Wie kann ich die Rahmenbedingungen für meine Öffentlichkeitsarbeit klären?',
#   'Category': 'General/other',
#   'Document': 'ae51e0f8'},
#  {'Question': 'Gibt es bestimmte Bedingungen für die Förderfähigkeit von Bekanntmachungen?',
#   'Category': 'General/other',
#   'Document': 'ae51e0f8'},
#  {'Question': 'Welche Schritte sind notwendig, um Öffentlichkeitsarbeit fördern zu lassen?',
#   'Category': 'General/other',
#   'Document': 'ae51e0f8'},
#  {'Question': 'Wo finde ich Informationen zur Abstimmung mit dem Projektträger?',
#   'Category': 'General/other',
#   'Document': 'ae51e0f8'},
#  {'Question': 'Wann kann ich die Inflationsausgleichsprämie abrechnen?',
#   'Category': 'General/other',
#   'Document': '597c8bab'},
#  {'Question': 'Gibt es Bedingungen für die Auszahlung der IAP?',
#   'Category': 'General/other',
#   'Document': '597c8bab'},
#  {'Question': 'Wie wird die Inflationsausgleichsprämie im TVÖD behandelt?',
#   'Category': 'General/other',
#   'Document': '597c8bab'},
#  {'Question': 'Was gilt für die Zuwendungsfähigkeit der Inflationsausgleichsprämie?',
#   'Category': 'General/other',
#   'Document': '597c8bab'},
#  {'Question': 'Welche Ausnahmen gibt es bei der IAP-Abrechnung?',
#   'Category': 'General/other',
#   'Document': '597c8bab'},
#  {'Question': 'Ist es möglich, die letzte Rechnung des dritten Quartals zu ändern?',
#   'Category': 'General/other',
#   'Document': 'eb29dbd2'},
#  {'Question': 'Wie kann ich Fehler in der Jahresabrechnung beheben?',
#   'Category': 'General/other',
#   'Document': 'eb29dbd2'},
#  {'Question': 'Gibt es eine Möglichkeit, die Abrechnung für das dritte Quartal anzupassen?',
#   'Category': 'General/other',
#   'Document': 'eb29dbd2'},
#  {'Question': 'Wann erhalte ich den Zwischennachweis für die Jahresabrechnung?',
#   'Category': 'General/other',
#   'Document': 'eb29dbd2'},
#  {'Question': 'Was passiert, wenn ich einen Fehler in der Abrechnung des letzten Quartals feststelle?',
#   'Category': 'General/other',
#   'Document': 'eb29dbd2'},
#  {'Question': 'Ist es möglich, die Endfassung eines Zuwendungsantrags zu modifizieren?',
#   'Category': 'General/other',
#   'Document': '9d80d897'},
#  {'Question': 'Wie gehe ich vor, wenn ich kleine Anpassungen in der Endfassung vornehmen möchte?',
#   'Category': 'General/other',
#   'Document': '9d80d897'},
#  {'Question': 'Was soll ich tun, wenn ich Änderungen an Zahlungsanforderungen vornehmen muss?',
#   'Category': 'General/other',
#   'Document': '9d80d897'},
#  {'Question': 'Kann ich handschriftliche Korrekturen in der endgültigen PDF-Version meines Antrags vornehmen?',
#   'Category': 'General/other',
#   'Document': '9d80d897'},
#  {'Question': 'Wie reiße ich eine bereits eingereichte Fassung in profi-Online zurück, um eine neue einzureichen?',
#   'Category': 'General/other',
#   'Document': '9d80d897'},
#  {'Question': 'Ist es möglich, mehr Geld für die Position 0817 zu beantragen?',
#   'Category': 'General/other',
#   'Document': 'dcdd85c5'},
#  {'Question': 'Welche Schritte sind erforderlich, wenn die Position 0817 um mehr als 20 % überschritten wird?',
#   'Category': 'General/other',
#   'Document': 'dcdd85c5'},
#  {'Question': 'Wie wird der Antrag auf Mittelumwidmung für Position 0817 eingereicht?',
#   'Category': 'General/other',
#   'Document': 'dcdd85c5'},
#  {'Question': 'Was passiert, nachdem ein Antrag auf Mittelumwidmung für die Position 0817 eingereicht wurde?',
#   'Category': 'General/other',
#   'Document': 'dcdd85c5'},
#  {'Question': 'Könnte die Gesamtzuwendung beeinflusst werden, wenn ich die Position 0817 überziehe?',
#   'Category': 'General/other',
#   'Document': 'dcdd85c5'},
#  {'Question': 'Gibt es Situationen, in denen finanzielle Mittel zurückgefordert werden können?',
#   'Category': 'General/other',
#   'Document': '4df01c9d'},
#  {'Question': 'Was passiert, wenn die Zuwendung nicht richtig verwendet wird?',
#   'Category': 'General/other',
#   'Document': '4df01c9d'},
#  {'Question': 'Wie läuft das Verfahren ab, wenn eine Rücknahme der Zuwendung bevorsteht?',
#   'Category': 'General/other',
#   'Document': '4df01c9d'},
#  {'Question': 'Unter welchen Bedingungen könnte die Unterstützung widerrufen werden?',
#   'Category': 'General/other',
#   'Document': '4df01c9d'},
#  {'Question': 'Wird der Empfänger vor einer Entscheidung zur Rücknahme der Zuwendung informiert?',
#   'Category': 'General/other',
#   'Document': '4df01c9d'},
#  {'Question': 'Ist es möglich, ein Projekt vorzeitig zu beenden?',
#   'Category': 'General/other',
#   'Document': 'cde8b705'},
#  {'Question': 'Wie werden bereits entstandene Lohnkosten bei einer Kündigung behandelt?',
#   'Category': 'General/other',
#   'Document': 'cde8b705'},
#  {'Question': 'Ändert sich die genehmigte Summe bei einer Projektkündigung?',
#   'Category': 'General/other',
#   'Document': 'cde8b705'},
#  {'Question': 'Wer trägt die zusätzlichen Kosten, die durch eine Projektbeendigung entstehen?',
#   'Category': 'General/other',
#   'Document': 'cde8b705'},
#  {'Question': 'Welche finanziellen Auswirkungen hat eine vorzeitige Projektkündigung?',
#   'Category': 'General/other',
#   'Document': 'cde8b705'},
#  {'Question': 'Ist eine digitale Einreichung ohne elektronische Signatur möglich?',
#   'Category': 'General/other',
#   'Document': '69ed056b'},
#  {'Question': 'Wie kann ich den Antrag digital ohne Signatur einreichen?',
#   'Category': 'General/other',
#   'Document': '69ed056b'},
#  {'Question': 'Was sind die verfügbaren Methoden für die digitale Antragseinreichung?',
#   'Category': 'General/other',
#   'Document': '69ed056b'},
#  {'Question': 'Kann ich das Easy-Online Formular nur digital nutzen?',
#   'Category': 'General/other',
#   'Document': '69ed056b'},
#  {'Question': 'Welche Schritte sind nötig, um das TAN Verfahren zu wählen?',
#   'Category': 'General/other',
#   'Document': '69ed056b'},
#  {'Question': 'Darf ich Kosten für Kongressgebühren in Rechnung stellen?',
#   'Category': 'General/other',
#   'Document': '75f5e096'},
#  {'Question': 'Wie gehe ich vor, wenn ich Gebühren für Veranstaltungen abrechnen möchte?',
#   'Category': 'General/other',
#   'Document': '75f5e096'},
#  {'Question': 'Kann ich bereits bewilligte Teilnahmegebühren geltend machen?',
#   'Category': 'General/other',
#   'Document': '75f5e096'},
#  {'Question': 'Was muss ich tun, wenn im Antrag keine Gebühren erwähnt wurden?',
#   'Category': 'General/other',
#   'Document': '75f5e096'},
#  {'Question': 'Benötige ich eine Genehmigung für die Abrechnung von Teilnahmegebühren?',
#   'Category': 'General/other',
#   'Document': '75f5e096'},
#  {'Question': 'Ist es möglich, einen Antrag zur Übertragung von Mitteln an Dritte zu stellen?',
#   'Category': 'General/other',
#   'Document': '550aae57'},
#  {'Question': 'Wann kann ich einen Antrag zur Mittelweiterleitung an Dritte einreichen?',
#   'Category': 'General/other',
#   'Document': '550aae57'},
#  {'Question': 'Welche Bedingungen müssen erfüllt sein, um Mittel an Dritte weiterzuleiten?',
#   'Category': 'General/other',
#   'Document': '550aae57'},
#  {'Question': 'Könnte ich während meiner Antragstellung Mittel an andere Personen weitergeben?',
#   'Category': 'General/other',
#   'Document': '550aae57'},
#  {'Question': 'Wo finde ich die Prüfkriterien für die Mittelweiterleitung an Dritte?',
#   'Category': 'General/other',
#   'Document': '550aae57'},
#  {'Question': 'Gibt es die Möglichkeit, gesperrte Gelder für andere Zwecke zu nutzen?',
#   'Category': 'General/other',
#   'Document': '27900fee'},
#  {'Question': 'Wie kann ich gesperrte Finanzen wieder freigeben?',
#   'Category': 'General/other',
#   'Document': '27900fee'},
#  {'Question': 'Was muss ich tun, um gesperrte Mittel zu entsperren?',
#   'Category': 'General/other',
#   'Document': '27900fee'},
#  {'Question': 'Sind gesperrte Mittel automatisch für die geplante Verwendung reserviert?',
#   'Category': 'General/other',
#   'Document': '27900fee'},
#  {'Question': 'Welche Bedingungen müssen erfüllt sein, um eine Entsperrung der Mittel zu erreichen?',
#   'Category': 'General/other',
#   'Document': '27900fee'},
#  {'Question': 'Ist es möglich, nur einen Teil meiner Arbeitszeit für ein Förderprojekt zu dokumentieren?',
#   'Category': 'General/other',
#   'Document': '483e34f1'},
#  {'Question': 'Wie muss mein Arbeitsvertrag für das Projekt aussehen?',
#   'Category': 'General/other',
#   'Document': '483e34f1'},
#  {'Question': 'Gibt es spezielle Anforderungen für die Angabe des Arbeitsumfangs?',
#   'Category': 'General/other',
#   'Document': '483e34f1'},
#  {'Question': 'Muss der gesamte Einsatz im Projekt in meinem Arbeitsvertrag aufgeführt werden?',
#   'Category': 'General/other',
#   'Document': '483e34f1'},
#  {'Question': 'Wie wird der prozentuale Anteil meiner Arbeitszeit im Projekt festgelegt?',
#   'Category': 'General/other',
#   'Document': '483e34f1'},
#  {'Question': 'Sind Auslandsprojekte kostenpflichtig für die Teilnehmer?',
#   'Category': 'General/other',
#   'Document': '96f9f53b'},
#  {'Question': 'Wie können wir die Auslandskosten für Projekttreffen nachweisen?',
#   'Category': 'General/other',
#   'Document': '96f9f53b'},
#  {'Question': 'Gibt es besondere Bedingungen für die Erstattung von Auslandsmeetings?',
#   'Category': 'General/other',
#   'Document': '96f9f53b'},
#  {'Question': 'Wer kann die Kosten für Treffen im Ausland geltend machen?',
#   'Category': 'General/other',
#   'Document': '96f9f53b'},
#  {'Question': 'Welche Voraussetzungen müssen erfüllt sein, um Ausgaben für Projekte im Ausland zu decken?',
#   'Category': 'General/other',
#   'Document': '96f9f53b'},
#  {'Question': 'Sind administrative Tätigkeiten für die Abrechnung im Projekt zulässig?',
#   'Category': 'General/other',
#   'Document': 'c1c2e750'},
#  {'Question': 'Welche Regeln gelten für die Abrechnung von administrativ tätigem Personal?',
#   'Category': 'General/other',
#   'Document': 'c1c2e750'},
#  {'Question': 'Wie werden administrative Kosten in Hochschulprojekten behandelt?',
#   'Category': 'General/other',
#   'Document': 'c1c2e750'},
#  {'Question': 'Können administrative Mitarbeiter für ihre Tätigkeiten im Projekt finanziert werden?',
#   'Category': 'General/other',
#   'Document': 'c1c2e750'},
#  {'Question': 'Was passiert mit den Kosten für administrative Tätigkeiten in Unternehmensprojekten?',
#   'Category': 'General/other',
#   'Document': 'c1c2e750'},
#  {'Question': 'Sind Honorare für festangestellte Projektleiter im Rahmen der Aufträge förderfähig?',
#   'Category': 'General/other',
#   'Document': '177a376d'},
#  {'Question': 'Gibt es eine maximale Vergütung für externe Fachkräfte in Honorarverträgen?',
#   'Category': 'General/other',
#   'Document': '177a376d'},
#  {'Question': 'Welche Regelungen gelten für die Zahlung an externe Dienstleister im Projekt?',
#   'Category': 'General/other',
#   'Document': '177a376d'},
#  {'Question': 'Wie wird der Stundensatz für externe Mitarbeitende festgelegt?',
#   'Category': 'General/other',
#   'Document': '177a376d'},
#  {'Question': 'Kann ich für externe Berater einen höheren Stundensatz als 125 € ansetzen?',
#   'Category': 'General/other',
#   'Document': '177a376d'},
#  {'Question': 'Wie können internationale Partner in ein Projekt integriert werden?',
#   'Category': 'General/other',
#   'Document': '7ed28eac'},
#  {'Question': 'Welche Voraussetzungen müssen ausländische Firmen für eine Zusammenarbeit erfüllen?',
#   'Category': 'General/other',
#   'Document': '7ed28eac'},
#  {'Question': 'Gibt es Möglichkeiten für nicht-deutsche Universitäten, an Förderprojekten teilzunehmen?',
#   'Category': 'General/other',
#   'Document': '7ed28eac'},
#  {'Question': 'Können ausländische Partner ohne finanzielle Unterstützung in ein Projekt eingebunden werden?',
#   'Category': 'General/other',
#   'Document': '7ed28eac'},
#  {'Question': 'Wie wird der Mehrwert ausländischer Partner für ein Verbundprojekt bewertet?',
#   'Category': 'General/other',
#   'Document': '7ed28eac'},
#  {'Question': 'Ist die digitale Archivierung von Belegen erlaubt?',
#   'Category': 'General/other',
#   'Document': '8683dcd1'},
#  {'Question': 'Was passiert mit den Originalbelegen, wenn ich digital archiviere?',
#   'Category': 'General/other',
#   'Document': '8683dcd1'},
#  {'Question': 'Muss ich Papierbelege aufbewahren, wenn ich digital arbeite?',
#   'Category': 'General/other',
#   'Document': '8683dcd1'},
#  {'Question': 'Gibt es Voraussetzungen für die digitale Archivierung von Dokumenten?',
#   'Category': 'General/other',
#   'Document': '8683dcd1'},
#  {'Question': 'Kann ich Originalbelege vernichten, wenn ich sie digital speichere?',
#   'Category': 'General/other',
#   'Document': '8683dcd1'},
#  {'Question': 'Wie wird sichergestellt, dass frühere Abrechnungsfehler automatisch korrigiert werden?',
#   'Category': 'General/other',
#   'Document': '100e942d'},
#  {'Question': 'Kann ich die Abrechnung für ein ganzes Jahr ändern, wenn ich einen Fehler finde?',
#   'Category': 'General/other',
#   'Document': '100e942d'},
#  {'Question': 'Was passiert mit bereits gemeldeten Kosten, wenn ich eine neue Zahlungsanforderung einreiche?',
#   'Category': 'General/other',
#   'Document': '100e942d'},
#  {'Question': 'Sind alle bisherigen Kosten in der aktuellen Abrechnung berücksichtigt?',
#   'Category': 'General/other',
#   'Document': '100e942d'},
#  {'Question': 'Wie funktioniert die Kumulierung der Kosten in den Zahlungsanforderungen?',
#   'Category': 'General/other',
#   'Document': '100e942d'},
#  {'Question': 'Dürfen Hochschulmitarbeiter gleichzeitig in mehreren Förderprojekten tätig sein?',
#   'Category': 'General/other',
#   'Document': '26026980'},
#  {'Question': 'Wie wird die Abrechnung von Mitarbeitenden geregelt, die in mehreren Projekten arbeiten?',
#   'Category': 'General/other',
#   'Document': '26026980'},
#  {'Question': 'Was muss im Arbeitsvertrag enthalten sein, wenn jemand an mehreren Projekten beteiligt ist?',
#   'Category': 'General/other',
#   'Document': '26026980'},
#  {'Question': 'Sind Mitarbeitende in Industrieunternehmen berechtigt, in verschiedenen Projekten mitzuarbeiten?',
#   'Category': 'General/other',
#   'Document': '26026980'},
#  {'Question': 'Wie erfolgt die Abrechnung für Personen, die anteilig in unterschiedlichen Projekten tätig sind?',
#   'Category': 'General/other',
#   'Document': '26026980'},
#  {'Question': 'Ist es möglich, dass mehrere Personen für die Nutzerverwaltung autorisiert sind?',
#   'Category': 'General/other',
#   'Document': 'ca130ae9'},
#  {'Question': 'Wie viele Benutzerverwalter können für eine Organisation eingerichtet werden?',
#   'Category': 'General/other',
#   'Document': 'ca130ae9'},
#  {'Question': 'Muss es immer mindestens einen Benutzerverwalter geben?',
#   'Category': 'General/other',
#   'Document': 'ca130ae9'},
#  {'Question': 'Dürfen mehrere Personen gleichzeitig die Nutzer verwalten?',
#   'Category': 'General/other',
#   'Document': 'ca130ae9'},
#  {'Question': 'Welche Anforderungen gelten für die Benutzerverwaltungsrechte?',
#   'Category': 'General/other',
#   'Document': 'ca130ae9'},
#  {'Question': 'Ist es möglich, eine Mittelumwidmung selbst in profi-Online zu beantragen?',
#   'Category': 'General/other',
#   'Document': '1616d754'},
#  {'Question': 'Wie reicht man einen Antrag auf Mittelumwidmung über die Online-Plattform ein?',
#   'Category': 'General/other',
#   'Document': '1616d754'},
#  {'Question': 'Was passiert, nachdem ich den Antrag auf Mittelumwidmung geschickt habe?',
#   'Category': 'General/other',
#   'Document': '1616d754'},
#  {'Question': 'Wie lange dauert es, bis ich eine Rückmeldung zu meinem Mittelumwidmungsantrag erhalte?',
#   'Category': 'General/other',
# ...
#   'Category': 'General/other',
#   'Document': '7c003862'},
#  {'Question': 'Was sollte ich zur Abrechnung der Energiepauschale beachten?',
#   'Category': 'General/other',
#   'Document': '7c003862'},
#  {'Question': 'In welcher Form kann der Arbeitgeber die Energiepauschale zurückerhalten?',
#   'Category': 'General/other',
#   'Document': '7c003862'},
#  {'Question': 'Wie sollte ich die Jahressonderzahlung in der Abrechnung behandeln?',
#   'Category': 'General/other',
#   'Document': '30a8088a'},
#  {'Question': 'Gibt es eine spezielle Vorlage für die Jahressonderzahlung?',
#   'Category': 'General/other',
#   'Document': '30a8088a'},
#  {'Question': 'Wo finde ich die Anleitung zur Abrechnung der Jahressonderzahlung?',
#   'Category': 'General/other',
#   'Document': '30a8088a'},
#  {'Question': 'Kann ich die Jahressonderzahlung in der regulären Belegliste auflisten?',
#   'Category': 'General/other',
#   'Document': '30a8088a'},
#  {'Question': 'Ist es nötig, die Jahressonderzahlung separat abzurechnen?',
#   'Category': 'General/other',
#   'Document': '30a8088a'},
#  {'Question': 'Wie kann ich das AZAP Formular abrufen?',
#   'Category': 'General/other',
#   'Document': '593218a9'},
#  {'Question': 'Wo ist das AZAP Formular in Easy Online zu finden?',
#   'Category': 'General/other',
#   'Document': '593218a9'},
#  {'Question': 'Welche Schritte sind notwendig, um das AZAP Formular zu selektieren?',
#   'Category': 'General/other',
#   'Document': '593218a9'},
#  {'Question': 'Kann ich das AZAP Formular direkt herunterladen?',
#   'Category': 'General/other',
#   'Document': '593218a9'},
#  {'Question': 'Gibt es eine Anleitung zur Nutzung des AZAP Formulars in Easy Online?',
#   'Category': 'General/other',
#   'Document': '593218a9'},
#  {'Question': 'Wie erhalte ich die Vorlage für den Abschlussbericht?',
#   'Category': 'General/other',
#   'Document': '1a90bbf0'},
#  {'Question': 'Gibt es spezielle Richtlinien zur Erstellung des Sachberichts?',
#   'Category': 'General/other',
#   'Document': '1a90bbf0'},
#  {'Question': 'Wo kann ich Informationen zu Gliederungen für den Sachbericht finden?',
#   'Category': 'General/other',
#   'Document': '1a90bbf0'},
#  {'Question': 'Wo liegt der Formularschrank des Bundes genau?',
#   'Category': 'General/other',
#   'Document': '1a90bbf0'},
#  {'Question': 'Was sind die NABF AZA und NKBF 2017AZK?',
#   'Category': 'General/other',
#   'Document': '1a90bbf0'},
#  {'Question': 'Wo kann ich die Gliederungsvorschläge für den Sachbericht finden?',
#   'Category': 'General/other',
#   'Document': '084d936b'},
#  {'Question': 'Gibt es ein spezifisches Dokument für den Abschlussbericht?',
#   'Category': 'General/other',
#   'Document': '084d936b'},
#  {'Question': 'Wie erhalte ich die benötigten Unterlagen für den Sachbericht?',
#   'Category': 'General/other',
#   'Document': '084d936b'},
#  {'Question': 'Wo finde ich den Formularschrank des Bundes für die Berichterstattung?',
#   'Category': 'General/other',
#   'Document': '084d936b'},
#  {'Question': 'Welche Links führen zu den Vorgaben für den Sachbericht?',
#   'Category': 'General/other',
#   'Document': '084d936b'},
#  {'Question': 'Wo kann ich das Tool zur Berechnung der Personalkosten NKBF2017 finden?',
#   'Category': 'General/other',
#   'Document': '20b8efbe'},
#  {'Question': 'Welche Optionen gibt es zur Erfassung produktiver Stunden für Personalkosten?',
#   'Category': 'General/other',
#   'Document': '20b8efbe'},
#  {'Question': 'Wie kann ich meine reduzierten Arbeitszeiten im Berechnungstool angeben?',
#   'Category': 'General/other',
#   'Document': '20b8efbe'},
#  {'Question': 'Welche Links führen zu den verschiedenen Personalkosten-Berechnungstools?',
#   'Category': 'General/other',
#   'Document': '20b8efbe'},
#  {'Question': 'Gibt es spezielle Tools für unterschiedliche Antragsarten im Zusammenhang mit Personalkosten?',
#   'Category': 'General/other',
#   'Document': '20b8efbe'},
#  {'Question': 'Wie erhalte ich die Vorlage für die Beschreibung eines Teilvorhabens?',
#   'Category': 'General/other',
#   'Document': '368733f2'},
#  {'Question': 'Welche Vorlage benötige ich für den Antrag auf Fördermittel?',
#   'Category': 'General/other',
#   'Document': '368733f2'},
#  {'Question': 'Wo kann ich die Teilvorhabenbeschreibung für AZK abrufen?',
#   'Category': 'General/other',
#   'Document': '368733f2'},
#  {'Question': 'Gibt es unterschiedliche Vorlagen für AZK und AZA?',
#   'Category': 'General/other',
#   'Document': '368733f2'},
#  {'Question': 'Wie unterscheidet sich die Teilvorhabenbeschreibung für verschiedene Fördermittel?',
#   'Category': 'General/other',
#   'Document': '368733f2'},
#  {'Question': 'Wo kann ich Informationen über geförderte Projekte abrufen?',
#   'Category': 'General/other',
#   'Document': '9b20be50'},
#  {'Question': 'Gibt es eine Website, auf der geförderte Projekte aufgelistet sind?',
#   'Category': 'General/other',
#   'Document': '9b20be50'},
#  {'Question': 'Wie erfahre ich von aktuellen BMBF-Projekten, die gefördert werden?',
#   'Category': 'General/other',
#   'Document': '9b20be50'},
#  {'Question': 'Könnten Sie mir den Link zur Übersicht geförderter Vorhaben mitteilen?',
#   'Category': 'General/other',
#   'Document': '9b20be50'},
#  {'Question': 'Wo finde ich Details zu den Projekten, die vom BMBF unterstützt werden?',
#   'Category': 'General/other',
#   'Document': '9b20be50'},
#  {'Question': 'Wo kann ich Informationen zur Förderung abrufen?',
#   'Category': 'General/other',
#   'Document': '1313c8a9'},
#  {'Question': 'Gibt es bestimmte Stellen, an denen ich Förderhinweise nachlesen kann?',
#   'Category': 'General/other',
#   'Document': '1313c8a9'},
#  {'Question': 'Wie komme ich an die Informationen zu Förderungen?',
#   'Category': 'General/other',
#   'Document': '1313c8a9'},
#  {'Question': 'In welchen Dokumenten finde ich die Hinweise zur Förderung?',
#   'Category': 'General/other',
#   'Document': '1313c8a9'},
#  {'Question': 'Wo sind die Informationen über die Fördermittel zu finden?',
#   'Category': 'General/other',
#   'Document': '1313c8a9'},
#  {'Question': 'Wo kann ich das Tool zur Berechnung von Personalkosten für Antragsteller finden?',
#   'Category': 'General/other',
#   'Document': '02771ffe'},
#  {'Question': 'Wie erhalte ich Zugriff auf das Personalberechnungstool für geförderte Zuwendungsempfänger?',
#   'Category': 'General/other',
#   'Document': '02771ffe'},
#  {'Question': 'Gibt es eine Möglichkeit, das Personalberechnungstool für Antragsteller auf Ausgabenbasis herunterzuladen?',
#   'Category': 'General/other',
#   'Document': '02771ffe'},
#  {'Question': 'Wo befindet sich das Tool für die Personalkostenberechnung für Zuwendungsempfänger?',
#   'Category': 'General/other',
#   'Document': '02771ffe'},
#  {'Question': 'Kann ich das Personalberechnungstool online einsehen oder herunterladen?',
#   'Category': 'General/other',
#   'Document': '02771ffe'},
#  {'Question': 'Wo kann ich die Vorlage für die Belegliste herunterladen?',
#   'Category': 'General/other',
#   'Document': 'b0516af9'},
#  {'Question': 'Gibt es eine spezielle Empfehlung für Hochschulen bezüglich der Belegliste?',
#   'Category': 'General/other',
#   'Document': 'b0516af9'},
#  {'Question': 'Wie unterstützt die Vorlage bei der Abrechnung der Jahressonderzahlung?',
#   'Category': 'General/other',
#   'Document': 'b0516af9'},
#  {'Question': 'Wo finde ich den Formularschrank des Bundes?',
#   'Category': 'General/other',
#   'Document': 'b0516af9'},
#  {'Question': 'Welche Links benötige ich, um die Belegliste zu erhalten?',
#   'Category': 'General/other',
#   'Document': 'b0516af9'},
#  {'Question': 'Wo finde ich Informationen zur Verfahrensart im Zuwendungsbescheid?',
#   'Category': 'General/other',
#   'Document': '10d9a73b'},
#  {'Question': 'Wie erkenne ich, ob das Abrufverfahren für mein Projekt gilt?',
#   'Category': 'General/other',
#   'Document': '10d9a73b'},
#  {'Question': 'In welchem Abschnitt des Zuwendungsbescheids sind die Hinweise zu finden?',
#   'Category': 'General/other',
#   'Document': '10d9a73b'},
#  {'Question': 'Erhalte ich zusätzliche Dokumente, wenn das Abrufverfahren anwendbar ist?',
#   'Category': 'General/other',
#   'Document': '10d9a73b'},
#  {'Question': 'Was sind die Nebenbestimmungen im Zuwendungsbescheid bezüglich der Auszahlung?',
#   'Category': 'General/other',
#   'Document': '10d9a73b'},
#  {'Question': 'Wo kann ich den Formularschrank finden?',
#   'Category': 'General/other',
#   'Document': '049a97fb'},
#  {'Question': 'Welche Adresse hat der Formularschrank?',
#   'Category': 'General/other',
#   'Document': '049a97fb'},
#  {'Question': 'Könnten Sie mir den Link zum Formularschrank geben?',
#   'Category': 'General/other',
#   'Document': '049a97fb'},
#  {'Question': 'Wie erlange ich Zugang zum Formularschrank?',
#   'Category': 'General/other',
#   'Document': '049a97fb'},
#  {'Question': 'Ist der Formularschrank online verfügbar?',
#   'Category': 'General/other',
#   'Document': '049a97fb'},
#  {'Question': 'Wie lade ich die Nachweise für die Verwendung hoch?',
#   'Category': 'General/other',
#   'Document': '61347d19'},
#  {'Question': 'Gibt es eine Plattform für den Upload meiner Dokumente?',
#   'Category': 'General/other',
#   'Document': '61347d19'},
#  {'Question': 'Welche Möglichkeiten habe ich, um große Dateien zu senden?',
#   'Category': 'General/other',
#   'Document': '61347d19'},
#  {'Question': 'Kann ich meine Unterlagen auch sicher online übermitteln?',
#   'Category': 'General/other',
#   'Document': '61347d19'},
#  {'Question': 'Wie erstelle ich den zahlenmäßigen Teil des Nachweises?',
#   'Category': 'General/other',
#   'Document': '61347d19'},
#  {'Question': 'Wie kann ich herausfinden, welche finanziellen Mittel nicht verfügbar sind?',
#   'Category': 'General/other',
#   'Document': 'e2948baf'},
#  {'Question': 'Wo finde ich die Informationen über gesperrte Mittel in meinem Zuwendungsbescheid?',
#   'Category': 'General/other',
#   'Document': 'e2948baf'},
#  {'Question': 'Welche Schritte muss ich unternehmen, um gesperrte Mittel freizugeben?',
#   'Category': 'General/other',
#   'Document': 'e2948baf'},
#  {'Question': 'Gibt es eine Übersicht, wo die Auflagen für die Entsperrung aufgeführt sind?',
#   'Category': 'General/other',
#   'Document': 'e2948baf'},
#  {'Question': 'Sind die gesperrten Mittel für eine Umwidmung in andere Positionen geeignet?',
#   'Category': 'General/other',
#   'Document': 'e2948baf'},
#  {'Question': 'Wie kann ich die Skizze des Antrags einreichen?',
#   'Category': 'General/other',
#   'Document': '0cb0365e'},
#  {'Question': 'Wo finde ich den Link zur Einreichung der ersten Antragsstufe?',
#   'Category': 'General/other',
#   'Document': '0cb0365e'},
#  {'Question': 'Gibt es eine bestimmte Stelle, an der ich meinen Antrag einreichen muss?',
#   'Category': 'General/other',
#   'Document': '0cb0365e'},
#  {'Question': 'Was muss ich beachten, wenn ich die Antragsunterlagen einreiche?',
#   'Category': 'General/other',
#   'Document': '0cb0365e'},
#  {'Question': 'Welche Informationen benötigt die Skizzeneinreichung?',
#   'Category': 'General/other',
#   'Document': '0cb0365e'},
#  {'Question': 'An welcher Stelle trage ich die Miete in der Abrechnung ein?',
#   'Category': 'General/other',
#   'Document': 'ed89e5d7'},
#  {'Question': 'Wie kann ich Mietausgaben korrekt abrechnen?',
#   'Category': 'General/other',
#   'Document': 'ed89e5d7'},
#  {'Question': 'Wo finde ich die Position für die Mietkosten in der Zahlungsanweisung?',
#   'Category': 'General/other',
#   'Document': 'ed89e5d7'},
#  {'Question': 'Welche Position benutze ich für die Miete in der Abrechnung?',
#   'Category': 'General/other',
#   'Document': 'ed89e5d7'},
#  {'Question': 'Wie gehe ich mit genehmigten Mietausgaben in der Zahlungsanweisung um?',
#   'Category': 'General/other',
#   'Document': 'ed89e5d7'},
#  {'Question': 'Welche Zwecke können mit der Projektpauschale von Hochschulen abgedeckt werden?',
#   'Category': 'General/other',
#   'Document': '690d44e5'},
#  {'Question': 'Was sind die zulässigen Ausgaben für die Projektpauschale, die von den Hochschulen empfangen wird?',
#   'Category': 'General/other',
#   'Document': '690d44e5'},
#  {'Question': 'Wie können Hochschulen die erhaltene Projektpauschale verwenden?',
#   'Category': 'General/other',
#   'Document': '690d44e5'},
#  {'Question': 'Ist ein Nachweis für die Verwendung der Projektpauschale notwendig?',
#   'Category': 'General/other',
#   'Document': '690d44e5'},
#  {'Question': 'Wer entscheidet über die Verwendung der Mittel aus der Projektpauschale?',
#   'Category': 'General/other',
#   'Document': '690d44e5'},
#  {'Question': 'Sind ausschließlich Forschungseinrichtungen im Konsortium erlaubt?',
#   'Category': 'Basisinformationen',
#   'Document': 'b67f72be'},
#  {'Question': 'Wo finde ich Details zu den Antragsberechtigen für das Projekt?',
#   'Category': 'Basisinformationen',
#   'Document': 'b67f72be'},
#  {'Question': 'Gibt es Einschränkungen für die Zusammensetzung des Konsortiums?',
#   'Category': 'Basisinformationen',
#   'Document': 'b67f72be'},
#  {'Question': 'Welche Informationen zu den Antragsberechtigten gelten für meine Förderung?',
#   'Category': 'Basisinformationen',
#   'Document': 'b67f72be'},
#  {'Question': 'Kann mein Konsortium auch andere Institutionen als Forschungsorganisationen einbeziehen?',
#   'Category': 'Basisinformationen',
#   'Document': 'b67f72be'},
#  {'Question': 'Ist es möglich, dass mehrere Mitarbeiter die Benutzerverwaltung in profi-online übernehmen?',
#   'Category': 'Basisinformationen',
#   'Document': '494542e7'},
#  {'Question': 'Wie viele Personen können die Rechte zur Nutzerverwaltung erhalten?',
#   'Category': 'Basisinformationen',
#   'Document': '494542e7'},
#  {'Question': 'Muss immer mindestens ein Benutzerverwalter eingerichtet sein?',
#   'Category': 'Basisinformationen',
#   'Document': '494542e7'},
#  {'Question': 'Können alle Nutzer eines Zuwendungsempfängers Benutzerverwalter werden?',
#   'Category': 'Basisinformationen',
#   'Document': '494542e7'},
#  {'Question': 'Welche Anforderungen gibt es für die Einrichtung eines Benutzerverwalters?',
#   'Category': 'Basisinformationen',
#   'Document': '494542e7'},
#  {'Question': 'In welchen Fällen sollten Projektleitende auf profi-Online zugreifen?',
#   'Category': 'Basisinformationen',
#   'Document': '4522eca6'},
#  {'Question': 'Wer entscheidet über den Zugang von Projektleitenden zu profi-Online?',
#   'Category': 'Basisinformationen',
#   'Document': '4522eca6'},
#  {'Question': 'Ist es notwendig, dass Projektleitende Zugang zu profi-Online haben?',
#   'Category': 'Basisinformationen',
#   'Document': '4522eca6'},
#  {'Question': 'Was müssen Projektleitende tun, um profi-Online zu nutzen?',
#   'Category': 'Basisinformationen',
#   'Document': '4522eca6'},
#  {'Question': 'Benötigen Projektleitende einen Online-Zugang für spezifische Aufgaben?',
#   'Category': 'Basisinformationen',
#   'Document': '4522eca6'},
#  {'Question': 'Wie erhalten wir den Zugang zu profi-online?',
#   'Category': 'Basisinformationen',
#   'Document': '4119ebdc'},
#  {'Question': 'An wen müssen wir den Antrag für profi-online senden?',
#   'Category': 'Basisinformationen',
#   'Document': '4119ebdc'},
#  {'Question': 'Wer ist für die Freischaltung des profi-online Zugangs zuständig?',
#   'Category': 'Basisinformationen',
#   'Document': '4119ebdc'},
#  {'Question': 'Wie funktioniert die Freigabe für profi-online?',
#   'Category': 'Basisinformationen',
#   'Document': '4119ebdc'},
#  {'Question': 'Was müssen wir tun, um auf profi-online zugreifen zu können?',
#   'Category': 'Basisinformationen',
#   'Document': '4119ebdc'},
#  {'Question': 'Welche Unterlagen sind erforderlich, um die Bonität nachzuweisen?',
#   'Category': 'Basisinformationen',
#   'Document': 'd3a00cb7'},
#  {'Question': 'Was passiert, wenn kein geprüfter Jahresabschluss vorliegt?',
#   'Category': 'Basisinformationen',
#   'Document': 'd3a00cb7'},
#  {'Question': 'Wie wird die Bonitätsprüfung für Unternehmen durchgeführt?',
#   'Category': 'Basisinformationen',
#   'Document': 'd3a00cb7'},
#  {'Question': 'Gibt es spezielle Anforderungen für kleine und mittlere Unternehmen bei der Prüfung?',
#   'Category': 'Basisinformationen',
#   'Document': 'd3a00cb7'},
#  {'Question': 'Wie lange dauert der Prozess der Bonitätsprüfung und was wird genau geprüft?',
#   'Category': 'Basisinformationen',
#   'Document': 'd3a00cb7'},
#  ...]

# %%
relevance_total = []

for q in tqdm(ground_truth):
    doc_id = q['Document']
    results = elastic_search(query=q['Question'], category=q['Category'])
    relevance = [d['id'] == doc_id for d in results]
    relevance_total.append(relevance)
# Out:
#   0%|          | 0/2145 [00:00<?, ?it/s]/var/folders/81/16mr_0gj603btxm2xxhl704c0000gn/T/ipykernel_4391/2931147547.py:26: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   response = es_client.search(index=index_name, body=search_query)
# 100%|██████████| 2145/2145 [00:24<00:00, 88.01it/s]

# %% [markdown]
# - We iterate over all our queries in our ground truth, and check if our "ground truth" ID is among our results

# %%
example = [
    [True, False, False, False, False], # 1, 
    [False, False, False, False, False], # 0
    [False, False, False, False, False], # 0 
    [False, False, False, False, False], # 0
    [False, False, False, False, False], # 0 
    [True, False, False, False, False], # 1
    [True, False, False, False, False], # 1
    [True, False, False, False, False], # 1
    [True, False, False, False, False], # 1
    [True, False, False, False, False], # 1 
    [False, False, True, False, False],  # 1/3
    [False, False, False, False, False], # 0
]

# 1 => 1
# 2 => 1 / 2 = 0.5
# 3 => 1 / 3 = 0.3333
# 4 => 0.25
# 5 => 0.2
# rank => 1 / rank
# none => 0

# %%
def hit_rate(relevance_total):
    cnt = 0

    for line in relevance_total:
        if True in line:
            cnt = cnt + 1

    return cnt / len(relevance_total)

# %%
def mrr(relevance_total):
    total_score = 0.0

    for line in relevance_total:
        for rank in range(len(line)):
            if line[rank] == True:
                total_score = total_score + 1 / (rank + 1)

    return total_score / len(relevance_total)

# %%
hit_rate(example)
# Out:
# 0.5833333333333334

# %%
mrr(example)
# Out:
# 0.5277777777777778

# %% [markdown]
# - hit-rate (recall)
# - Mean Reciprocal Rank (mrr)

# %%
hit_rate(relevance_total), mrr(relevance_total)
# Out:
# (0.6088578088578088, 0.46031080031080174)

# %%
import minsearch

# Define the index, specifying the text and keyword fields based on your documents
index = minsearch.Index(
    text_fields=["Question", "Answer"],   # Text fields to search (Question and Answer)
    keyword_fields=["Category", "id"]     # Keyword fields (Category and id)
)

# Fit the index with your documents DataFrame
index.fit(documents)

# %%
def minsearch_search(query, category=None):
    # Define the boost for specific fields (giving more weight to 'Question')
    boost = {'Question': 3.0, 'Answer': 1.0}

    # Define the filter, if a category is provided
    filter_dict = {'Category': category} if category else {}

    # Perform the search with the query, filter, and boost
    results = index.search(
        query=query,
        filter_dict=filter_dict,  # Filter by 'Category' if provided
        boost_dict=boost,         # Boost 'Question' more than 'Answer'
        num_results=5             # Limit results to 5
    )

    return results

# %%
relevance_total = []

for q in tqdm(ground_truth):
    doc_id = q['Document']  # Assuming 'document' refers to the document's ID in the ground truth
    category = q['Category']  # Assuming the ground truth has a 'Category' field

    # Perform the search with the question and category
    results = minsearch_search(query=q['Question'], category=category)

    # Check if the correct document is in the search results
    relevance = [d['id'] == doc_id for d in results]
    relevance_total.append(relevance)
# Out:
# 100%|██████████| 2145/2145 [00:04<00:00, 432.50it/s]

# %%
hit_rate(relevance_total), mrr(relevance_total)
# Out:
# (0.5738927738927739, 0.43766122766122884)

# %% [markdown]
# Compare with ES results:
# ```
# (0.6088578088578088, 0.46031080031080174)
# ```

# %%
def evaluate(ground_truth, search_function):
    relevance_total = []

    for q in tqdm(ground_truth):
        doc_id = q['Document']
        results = search_function(q)
        relevance = [d['id'] == doc_id for d in results]
        relevance_total.append(relevance)

    return {
        'hit_rate': hit_rate(relevance_total),
        'mrr': mrr(relevance_total),
    }

# %% [markdown]
# - ES and minsearch again as overview:

# %%
evaluate(ground_truth, lambda q: elastic_search(q['Question'], q['Category']))
# Out:
#   0%|          | 0/2145 [00:00<?, ?it/s]/var/folders/81/16mr_0gj603btxm2xxhl704c0000gn/T/ipykernel_4391/2931147547.py:26: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   response = es_client.search(index=index_name, body=search_query)
# 100%|██████████| 2145/2145 [00:42<00:00, 49.89it/s]
# {'hit_rate': 0.6088578088578088, 'mrr': 0.46031080031080174}

# %%
evaluate(ground_truth, lambda q: minsearch_search(q['Question'], q['Category']))
# Out:
# 100%|██████████| 2145/2145 [00:05<00:00, 427.71it/s]
# {'hit_rate': 0.5738927738927739, 'mrr': 0.43766122766122884}
